# %% [markdown]
# <a href="https://www.kaggle.com/code/sudhanshu2198/ipl-sports-analysis-using-sql?scriptVersionId=220206761" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
conn=sqlite3.connect("/kaggle/input/ipldatabase/database.sqlite")

# %% [markdown]
# # Indian Premier League

# %% [markdown]
# (<a href="https://ibb.co/k1H0jRm"><img src="https://i.ibb.co/gVjwN54/IPL.webp" alt="IPL" border="0" /></a>)

# %% [markdown]
# **Indian Premier League (IPL)** is a men's T20 franchise cricket league in India. It is annually contested by ten teams based on a round-robin group and knockout format, has teams in major Indian cities. The IPL has developed into the most lucrative and most popular outlet for the game of cricket. The brand value of the IPL in 2022 was **₹90,038 crore (US $ 11 billion)**.
#
# The top four teams contest three play-off matches, with one losing team being given a second chance to reach the final, a wrinkle aimed at maximizing potential television revenue. The play-off portion of the tournament involves the four teams that finished at the top of the tables in a series of knockout games that allows one team that lost its first-round game a second chance to advance to the final match.

# %% [markdown]
# ![Knock Out Format](https://staticg.sportskeeda.com/wp-content/uploads/2016/05/capture-1462822901-800.png)

# %% [markdown]
# ### Database Schema

# %% [markdown]
# <a href="https://ibb.co/RyBt71B"><img src="https://i.ibb.co/HdxRX0x/Database-Schema.png" alt="Database-Schema" border="0"></a>

# %% [markdown]
# ### Objective
#
# The objective of this notebook is to do a rigorous analysis of Indian Prenier League Database, answering multiple comman questions that cricketting fans have like top scorer, best Captain, best death over Specialist and many more. This notebook can be extremely helpful to people who knows and applied SQL on dummy database but want to practise on a Real Database, along with structured framework( where every query builds on previous queries) and questions to help them start.The notebook contains 30+ Advance queries covering nested case,aggregrate,different types of join,groupby
# and multiple table join.
#
# **[Medium Article Link](https://medium.com/@sudhanshurastogi/indian-premier-league-analysis-using-sql-3b8d1f61565a)**
#
# **[SQL Learning and Practising Resources Link](https://www.kaggle.com/discussions/questions-and-answers/350791)**
#
# **[Kaggle Notebook Link](https://www.kaggle.com/code/sudhanshu2198/ipl-sports-analysis-using-sql)**
#
# **[Database Schema Image Link](https://i.imgur.com/327NVKH.png)**

# %% [markdown]
# ### Bowling Statistics

# %%
#Bowlers who have bowled most deliveries

sql="""SELECT Player_Name,c.Country_Name,d.Bowling_skill,count(*) as Deliveries
       FROM Ball_by_Ball a
       join Player b
       on a.Bowler==b.Player_Id
       join Country c
       on b.Country_Name==c.Country_Id
       join Bowling_Style d
       on b.Bowling_skill==d.Bowling_Id
       group by Bowler
       order by Deliveries desc ;"""

bowling=pd.read_sql(sql, conn)
bowling.head().style.background_gradient(subset=["Deliveries"],cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_98c77_row0_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_98c77_row1_col3 {
#   background-color: #fd9627;
#   color: #000000;
# }
# #T_98c77_row2_col3 {
#   background-color: #e66a11;
#   color: #f1f1f1;
# }
# #T_98c77_row3_col3 {
#   background-color: #e3660f;
#   color: #f1f1f1;
# }
# #T_98c77_row4_col3 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_98c77_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Bowling_skill</th>
#       <th class="col_heading level0 col3" >Deliveries</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98c77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98c77_row0_col0" class="data row0 col0" >Harbhajan Singh</td>
#       <td id="T_98c77_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_98c77_row0_col2" class="data row0 col2" >Right-arm offbreak</td>
#       <td id="T_98c77_row0_col3" class="data row0 col3" >2742</td>
#     </tr>
#     <tr>
#       <th id="T_98c77_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98c77_row1_col0" class="data row1 col0" >P Kumar</td>
#       <td id="T_98c77_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_98c77_row1_col2" class="data row1 col2" >Right-arm medium</td>
#       <td id="T_98c77_row1_col3" class="data row1 col3" >2529</td>
#     </tr>
#     <tr>
#       <th id="T_98c77_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98c77_row2_col0" class="data row2 col0" >PP Chawla</td>
#       <td id="T_98c77_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_98c77_row2_col2" class="data row2 col2" >Legbreak</td>
#       <td id="T_98c77_row2_col3" class="data row2 col3" >2472</td>
#     </tr>
#     <tr>
#       <th id="T_98c77_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98c77_row3_col0" class="data row3 col0" >A Mishra</td>
#       <td id="T_98c77_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_98c77_row3_col2" class="data row3 col2" >Legbreak</td>
#       <td id="T_98c77_row3_col3" class="data row3 col3" >2466</td>
#     </tr>
#     <tr>
#       <th id="T_98c77_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98c77_row4_col0" class="data row4 col0" >SL Malinga</td>
#       <td id="T_98c77_row4_col1" class="data row4 col1" >Sri Lanka</td>
#       <td id="T_98c77_row4_col2" class="data row4 col2" >Right-arm fast</td>
#       <td id="T_98c77_row4_col3" class="data row4 col3" >2407</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Highest Wicket takers in IPL
'''Runout, Retired hurt and Obstructing field are not counted as bowlers wicket''' 

sql=""" select Player_Name,count(Kind_Out) as Wickets,
        sum(case when Kind_Out==1 then 1 else 0 end) as caught,
        sum(case when Kind_Out==2 then 1 else 0 end) as bowled,
        sum(case when Kind_Out==4 then 1 else 0 end) as lbw,
        sum(case when Kind_Out==6 then 1 else 0 end) as stumped
        from Wicket_Taken a
        join Ball_by_Ball b
        on a.Match_Id=b.Match_Id 
        and a.Innings_No=b.Innings_No
        and a.Over_Id=b.Over_Id 
        and a.Ball_Id=b.Ball_Id
        join (select Player_Id,Player_Name,b.Country_Name, c.Bowling_skill
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Bowling_Style c
              on a.Bowling_skill=c.Bowling_Id) c
        on b.Bowler=c.Player_Id
        where Kind_Out in (1,2,4,6,7,8)
        group by c.Player_Id
        order by Wickets desc; """

wickets=pd.read_sql(sql, conn)
subset=["Wickets","caught","bowled","lbw","stumped","caught and bowled"]
wickets.head().style.background_gradient(subset=["Wickets"],cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_26a26_row0_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_26a26_row1_col1 {
#   background-color: #e96d13;
#   color: #f1f1f1;
# }
# #T_26a26_row2_col1 {
#   background-color: #d85a09;
#   color: #f1f1f1;
# }
# #T_26a26_row3_col1 {
#   background-color: #c44802;
#   color: #f1f1f1;
# }
# #T_26a26_row4_col1 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26a26_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Wickets</th>
#       <th class="col_heading level0 col2" >caught</th>
#       <th class="col_heading level0 col3" >bowled</th>
#       <th class="col_heading level0 col4" >lbw</th>
#       <th class="col_heading level0 col5" >stumped</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26a26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26a26_row0_col0" class="data row0 col0" >SL Malinga</td>
#       <td id="T_26a26_row0_col1" class="data row0 col1" >143</td>
#       <td id="T_26a26_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_26a26_row0_col3" class="data row0 col3" >59</td>
#       <td id="T_26a26_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_26a26_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_26a26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26a26_row1_col0" class="data row1 col0" >A Mishra</td>
#       <td id="T_26a26_row1_col1" class="data row1 col1" >124</td>
#       <td id="T_26a26_row1_col2" class="data row1 col2" >66</td>
#       <td id="T_26a26_row1_col3" class="data row1 col3" >21</td>
#       <td id="T_26a26_row1_col4" class="data row1 col4" >13</td>
#       <td id="T_26a26_row1_col5" class="data row1 col5" >21</td>
#     </tr>
#     <tr>
#       <th id="T_26a26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26a26_row2_col0" class="data row2 col0" >DJ Bravo</td>
#       <td id="T_26a26_row2_col1" class="data row2 col1" >122</td>
#       <td id="T_26a26_row2_col2" class="data row2 col2" >90</td>
#       <td id="T_26a26_row2_col3" class="data row2 col3" >18</td>
#       <td id="T_26a26_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_26a26_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_26a26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26a26_row3_col0" class="data row3 col0" >PP Chawla</td>
#       <td id="T_26a26_row3_col1" class="data row3 col1" >120</td>
#       <td id="T_26a26_row3_col2" class="data row3 col2" >56</td>
#       <td id="T_26a26_row3_col3" class="data row3 col3" >33</td>
#       <td id="T_26a26_row3_col4" class="data row3 col4" >14</td>
#       <td id="T_26a26_row3_col5" class="data row3 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_26a26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_26a26_row4_col0" class="data row4 col0" >Harbhajan Singh</td>
#       <td id="T_26a26_row4_col1" class="data row4 col1" >119</td>
#       <td id="T_26a26_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_26a26_row4_col3" class="data row4 col3" >25</td>
#       <td id="T_26a26_row4_col4" class="data row4 col4" >8</td>
#       <td id="T_26a26_row4_col5" class="data row4 col5" >14</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highest wicket taken by a bowler in an IPL match

sql=""" select Player_Name,Country_Name,Bowling_skill,
        Wickets||"-"||runs as Best
        from( select a.Bowler,a.Match_Id,count(Kind_Out) as Wickets
              from Ball_by_Ball a
              join Wicket_Taken b
              on a.Match_Id=b.Match_Id 
              and a.Innings_No=b.Innings_No
              and a.Over_Id=b.Over_Id 
              and a.Ball_Id=b.Ball_Id
              where Kind_Out in (1,2,4,6,7,8)
              group by a.Bowler,a.Match_Id) a
        join( select a.Bowler,a.Match_Id,
              sum(coalesce(Runs_Scored,0)+coalesce(Extra_Runs,0)) as runs
              from Ball_by_Ball a
              left join Batsman_Scored b 
              on a.Match_Id=b.Match_Id 
              and a.Innings_No=b.Innings_No
              and a.Over_Id=b.Over_Id 
              and a.Ball_Id=b.Ball_Id
              left join Extra_Runs c
              on a.Match_Id=c.Match_Id 
              and a.Innings_No=c.Innings_No
              and a.Over_Id=c.Over_Id 
              and a.Ball_Id=c.Ball_Id
              group by a.Bowler,a.Match_Id) b
              on a.Bowler=b.Bowler
              and a.Match_Id=b.Match_Id
        join( select Player_Id,Player_Name,b.Country_Name, c.Bowling_skill
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Bowling_Style c
              on a.Bowling_skill=c.Bowling_Id) c
        on a.Bowler=c.Player_Id
        order by Wickets desc; """

highest_wicket=pd.read_sql(sql, conn)
highest_wicket.head()
# Out:
#        Player_Name Country_Name           Bowling_skill  Best
# 0    Sohail Tanvir     Pakistan    Left-arm medium-fast  6-15
# 1          A Zampa    Australia         Legbreak googly  6-19
# 2        RA Jadeja        India  Slow left-arm orthodox  5-16
# 3  Harbhajan Singh        India      Right-arm offbreak  5-18
# 4         I Sharma        India   Right-arm fast-medium  5-13

# %%
# No of 5-wicket hauls by bowlers in an IPL 

sql=""" select Player_Name,Country_Name,Bowling_skill,
        count(*) as hauls
        from (select Player_Id,Player_Name,Country_Name,Bowling_skill,
              count(Kind_Out) as Wickets
              from Wicket_Taken a
              join Ball_by_Ball b
              on a.Match_Id=b.Match_Id 
              and a.Innings_No=b.Innings_No
              and a.Over_Id=b.Over_Id 
              and a.Ball_Id=b.Ball_Id
              join (select Player_Id,Player_Name,b.Country_Name, c.Bowling_skill
                    from Player a
                    join Country b
                    on a.Country_Name=b.Country_Id
                    join Bowling_Style c
                    on a.Bowling_skill=c.Bowling_Id) c
             on b.Bowler=c.Player_Id
             where Kind_Out in (1,2,4,6,7,8)
             group by c.Player_Id,a.Match_Id
             having Wickets >=5)
             group by Player_Id
             order by hauls desc; """

highest_wicket=pd.read_sql(sql, conn)
highest_wicket.head().style.background_gradient(subset=["hauls"],cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_ebe39_row0_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_ebe39_row1_col3, #T_ebe39_row2_col3, #T_ebe39_row3_col3, #T_ebe39_row4_col3 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ebe39_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Bowling_skill</th>
#       <th class="col_heading level0 col3" >hauls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebe39_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebe39_row0_col0" class="data row0 col0" >JP Faulkner</td>
#       <td id="T_ebe39_row0_col1" class="data row0 col1" >Australia</td>
#       <td id="T_ebe39_row0_col2" class="data row0 col2" >Left-arm fast-medium</td>
#       <td id="T_ebe39_row0_col3" class="data row0 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ebe39_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ebe39_row1_col0" class="data row1 col0" >A Zampa</td>
#       <td id="T_ebe39_row1_col1" class="data row1 col1" >Australia</td>
#       <td id="T_ebe39_row1_col2" class="data row1 col2" >Legbreak googly</td>
#       <td id="T_ebe39_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ebe39_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ebe39_row2_col0" class="data row2 col0" >JD Unadkat</td>
#       <td id="T_ebe39_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_ebe39_row2_col2" class="data row2 col2" >Left-arm medium</td>
#       <td id="T_ebe39_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ebe39_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ebe39_row3_col0" class="data row3 col0" >SP Narine</td>
#       <td id="T_ebe39_row3_col1" class="data row3 col1" >West Indies</td>
#       <td id="T_ebe39_row3_col2" class="data row3 col2" >Right-arm offbreak</td>
#       <td id="T_ebe39_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ebe39_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ebe39_row4_col0" class="data row4 col0" >SL Malinga</td>
#       <td id="T_ebe39_row4_col1" class="data row4 col1" >Sri Lanka</td>
#       <td id="T_ebe39_row4_col2" class="data row4 col2" >Right-arm fast</td>
#       <td id="T_ebe39_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Most Runs Conceded by a Bowler in an IPL Match

sql=""" select Player_Name,Country_Name,Bowling_skill,runs
        from( select a.Bowler,
              sum(coalesce(Runs_Scored,0)+coalesce(Extra_Runs,0)) as runs
              from Ball_by_Ball a
              left join Batsman_Scored b 
              on a.Match_Id=b.Match_Id 
              and a.Innings_No=b.Innings_No
              and a.Over_Id=b.Over_Id 
              and a.Ball_Id=b.Ball_Id
              left join Extra_Runs c
              on a.Match_Id=c.Match_Id 
              and a.Innings_No=c.Innings_No
              and a.Over_Id=c.Over_Id 
              and a.Ball_Id=c.Ball_Id
              group by a.Bowler,a.Match_Id) a
        join( select Player_Id,Player_Name,b.Country_Name, c.Bowling_skill
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Bowling_Style c
              on a.Bowling_skill=c.Bowling_Id) b
        on a.Bowler=b.Player_Id
        order by runs desc; """

runs_concede_in_match=pd.read_sql(sql, conn)
runs_concede_in_match.head().style.background_gradient(subset=["runs"],cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_cee8f_row0_col3, #T_cee8f_row1_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_cee8f_row2_col3 {
#   background-color: #fedf88;
#   color: #000000;
# }
# #T_cee8f_row3_col3, #T_cee8f_row4_col3 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cee8f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Bowling_skill</th>
#       <th class="col_heading level0 col3" >runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cee8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cee8f_row0_col0" class="data row0 col0" >I Sharma</td>
#       <td id="T_cee8f_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_cee8f_row0_col2" class="data row0 col2" >Right-arm fast-medium</td>
#       <td id="T_cee8f_row0_col3" class="data row0 col3" >66</td>
#     </tr>
#     <tr>
#       <th id="T_cee8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cee8f_row1_col0" class="data row1 col0" >Sandeep Sharma</td>
#       <td id="T_cee8f_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_cee8f_row1_col2" class="data row1 col2" >Right-arm medium</td>
#       <td id="T_cee8f_row1_col3" class="data row1 col3" >66</td>
#     </tr>
#     <tr>
#       <th id="T_cee8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cee8f_row2_col0" class="data row2 col0" >UT Yadav</td>
#       <td id="T_cee8f_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_cee8f_row2_col2" class="data row2 col2" >Right-arm fast-medium</td>
#       <td id="T_cee8f_row2_col3" class="data row2 col3" >65</td>
#     </tr>
#     <tr>
#       <th id="T_cee8f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cee8f_row3_col0" class="data row3 col0" >AB Dinda</td>
#       <td id="T_cee8f_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_cee8f_row3_col2" class="data row3 col2" >Right-arm medium-fast</td>
#       <td id="T_cee8f_row3_col3" class="data row3 col3" >63</td>
#     </tr>
#     <tr>
#       <th id="T_cee8f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cee8f_row4_col0" class="data row4 col0" >VR Aaron</td>
#       <td id="T_cee8f_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_cee8f_row4_col2" class="data row4 col2" >Right-arm fast</td>
#       <td id="T_cee8f_row4_col3" class="data row4 col3" >63</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highest Runs Concede in an IPL over by a bowler

sql=""" select Player_Name as Bowler,
        max(runs+extra) as Runs,Fours,Sixes,
        Extra,wides,noballs,legbyes
        from(select Match_Id,Innings_No,Over_Id,sum(Runs_Scored) as runs,
             sum(case when Runs_Scored==4 then 1 else 0 end) as Fours,
             sum(case when Runs_Scored==6 then 1 else 0 end) as Sixes
             from Batsman_Scored
             group by Match_Id, Innings_No,Over_Id) a
        join(select Match_Id,Innings_No,Over_Id,sum(Extra_Runs) as Extra,
             sum(case when Extra_Type_Id==1 then 1 else 0 end) as legbyes,
             sum(case when Extra_Type_Id==2 then 1 else 0 end) as wides,
             sum(case when Extra_Type_Id==4 then 1 else 0 end) as noballs
             from Extra_Runs
             group by Match_Id,Innings_No,Over_Id) b
        on a.Match_Id=b.Match_Id 
        and a.Innings_No=b.Innings_No
        and a.Over_Id=b.Over_Id
        join (select Match_Id,Innings_No,Over_Id,Player_Name,
              c.Bowling_skill,d.Country_Name
              from Ball_by_Ball a
              join Player b
              on a.Bowler=b.Player_Id
              join Bowling_Style c
              on b.Bowling_skill=c.Bowling_Id
              join Country d
              on b.Country_Name=d.Country_Id
              group by Match_Id,Innings_No,Over_id) c
         on a.Match_Id=c.Match_Id 
         and a.Innings_No=c.Innings_No
         and a.Over_Id=c.Over_Id
         group by a.Match_Id,a.Innings_No,a.Over_Id
         order by Runs desc; """

most_runs_in_over=pd.read_sql(sql, conn)
most_runs_in_over.head().style.background_gradient(subset=["Runs"],cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_b0cd3_row0_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_b0cd3_row1_col1, #T_b0cd3_row2_col1 {
#   background-color: #fec859;
#   color: #000000;
# }
# #T_b0cd3_row3_col1 {
#   background-color: #ec7014;
#   color: #f1f1f1;
# }
# #T_b0cd3_row4_col1 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0cd3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Bowler</th>
#       <th class="col_heading level0 col1" >Runs</th>
#       <th class="col_heading level0 col2" >Fours</th>
#       <th class="col_heading level0 col3" >Sixes</th>
#       <th class="col_heading level0 col4" >Extra</th>
#       <th class="col_heading level0 col5" >wides</th>
#       <th class="col_heading level0 col6" >noballs</th>
#       <th class="col_heading level0 col7" >legbyes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0cd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0cd3_row0_col0" class="data row0 col0" >P Parameswaran</td>
#       <td id="T_b0cd3_row0_col1" class="data row0 col1" >37</td>
#       <td id="T_b0cd3_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_b0cd3_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_b0cd3_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_b0cd3_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_b0cd3_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_b0cd3_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b0cd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0cd3_row1_col0" class="data row1 col0" >RS Bopara</td>
#       <td id="T_b0cd3_row1_col1" class="data row1 col1" >33</td>
#       <td id="T_b0cd3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_b0cd3_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_b0cd3_row1_col4" class="data row1 col4" >7</td>
#       <td id="T_b0cd3_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_b0cd3_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_b0cd3_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b0cd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b0cd3_row2_col0" class="data row2 col0" >P Awana</td>
#       <td id="T_b0cd3_row2_col1" class="data row2 col1" >33</td>
#       <td id="T_b0cd3_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_b0cd3_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_b0cd3_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_b0cd3_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_b0cd3_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_b0cd3_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b0cd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b0cd3_row3_col0" class="data row3 col0" >DJ Bravo</td>
#       <td id="T_b0cd3_row3_col1" class="data row3 col1" >30</td>
#       <td id="T_b0cd3_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_b0cd3_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_b0cd3_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_b0cd3_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_b0cd3_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_b0cd3_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b0cd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b0cd3_row4_col0" class="data row4 col0" >RP Singh</td>
#       <td id="T_b0cd3_row4_col1" class="data row4 col1" >28</td>
#       <td id="T_b0cd3_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_b0cd3_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_b0cd3_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_b0cd3_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_b0cd3_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_b0cd3_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# best economy bowler's in IPL

sql=""" select Player_Name,Country_Name,
        overs,runs,extras,economy
        from(select Bowler,sum(coalesce(Extra_Runs,0)+Runs_Scored) as runs,
             sum(coalesce(Extra_Runs,0)) as extras,
             count(*)/6 as overs,
             round(round(sum(coalesce(Extra_Runs,0)+Runs_Scored),2)/round(count(*)/6,2),2) as economy
             from Batsman_Scored a
             join Ball_by_Ball b
             on a.Match_Id=b.Match_Id
             and a.Innings_No=b.Innings_No
             and a.Over_Id=b.Over_Id
             and a.Ball_Id=b.Ball_Id
             left join Extra_Runs c
             on a.Match_Id=c.Match_Id
             and a.Innings_No=c.Innings_No
             and a.Over_Id=c.Over_Id
             and a.Ball_Id=c.Ball_Id
             group by Bowler
             having overs>=50) a
        join (select Player_Id,Player_Name,b.Bowling_skill,c.Country_Name
              from Player a
              join Bowling_Style b
              on a.Bowling_skill=b.Bowling_Id
              join Country c
              on a.Country_Name=c.Country_Id) b
        on a.Bowler=b.Player_Id 
        order by economy asc; """

best_economy=pd.read_sql(sql, conn)
display(best_economy.head(10).style.background_gradient(subset=["economy"],cmap="YlOrBr_r",low=0.25))
# Out:
# <style type="text/css">
# #T_74ffb_row0_col5 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_74ffb_row1_col5 {
#   background-color: #f27d1b;
#   color: #f1f1f1;
# }
# #T_74ffb_row2_col5 {
#   background-color: #feab39;
#   color: #000000;
# }
# #T_74ffb_row3_col5 {
#   background-color: #feb945;
#   color: #000000;
# }
# #T_74ffb_row4_col5 {
#   background-color: #febe4a;
#   color: #000000;
# }
# #T_74ffb_row5_col5 {
#   background-color: #fedb80;
#   color: #000000;
# }
# #T_74ffb_row6_col5 {
#   background-color: #fee28e;
#   color: #000000;
# }
# #T_74ffb_row7_col5 {
#   background-color: #fffbcf;
#   color: #000000;
# }
# #T_74ffb_row8_col5 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_74ffb_row9_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_74ffb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >overs</th>
#       <th class="col_heading level0 col3" >runs</th>
#       <th class="col_heading level0 col4" >extras</th>
#       <th class="col_heading level0 col5" >economy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74ffb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74ffb_row0_col0" class="data row0 col0" >SP Narine</td>
#       <td id="T_74ffb_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_74ffb_row0_col2" class="data row0 col2" >263</td>
#       <td id="T_74ffb_row0_col3" class="data row0 col3" >1657</td>
#       <td id="T_74ffb_row0_col4" class="data row0 col4" >52</td>
#       <td id="T_74ffb_row0_col5" class="data row0 col5" >6.300000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74ffb_row1_col0" class="data row1 col0" >R Ashwin</td>
#       <td id="T_74ffb_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_74ffb_row1_col2" class="data row1 col2" >383</td>
#       <td id="T_74ffb_row1_col3" class="data row1 col3" >2475</td>
#       <td id="T_74ffb_row1_col4" class="data row1 col4" >66</td>
#       <td id="T_74ffb_row1_col5" class="data row1 col5" >6.460000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74ffb_row2_col0" class="data row2 col0" >SL Malinga</td>
#       <td id="T_74ffb_row2_col1" class="data row2 col1" >Sri Lanka</td>
#       <td id="T_74ffb_row2_col2" class="data row2 col2" >386</td>
#       <td id="T_74ffb_row2_col3" class="data row2 col3" >2534</td>
#       <td id="T_74ffb_row2_col4" class="data row2 col4" >127</td>
#       <td id="T_74ffb_row2_col5" class="data row2 col5" >6.560000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_74ffb_row3_col0" class="data row3 col0" >DW Steyn</td>
#       <td id="T_74ffb_row3_col1" class="data row3 col1" >South Africa</td>
#       <td id="T_74ffb_row3_col2" class="data row3 col2" >347</td>
#       <td id="T_74ffb_row3_col3" class="data row3 col3" >2287</td>
#       <td id="T_74ffb_row3_col4" class="data row3 col4" >78</td>
#       <td id="T_74ffb_row3_col5" class="data row3 col5" >6.590000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_74ffb_row4_col0" class="data row4 col0" >A Kumble</td>
#       <td id="T_74ffb_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_74ffb_row4_col2" class="data row4 col2" >161</td>
#       <td id="T_74ffb_row4_col3" class="data row4 col3" >1063</td>
#       <td id="T_74ffb_row4_col4" class="data row4 col4" >36</td>
#       <td id="T_74ffb_row4_col5" class="data row4 col5" >6.600000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_74ffb_row5_col0" class="data row5 col0" >M Muralitharan</td>
#       <td id="T_74ffb_row5_col1" class="data row5 col1" >Sri Lanka</td>
#       <td id="T_74ffb_row5_col2" class="data row5 col2" >256</td>
#       <td id="T_74ffb_row5_col3" class="data row5 col3" >1709</td>
#       <td id="T_74ffb_row5_col4" class="data row5 col4" >67</td>
#       <td id="T_74ffb_row5_col5" class="data row5 col5" >6.680000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_74ffb_row6_col0" class="data row6 col0" >GD McGrath</td>
#       <td id="T_74ffb_row6_col1" class="data row6 col1" >Australia</td>
#       <td id="T_74ffb_row6_col2" class="data row6 col2" >54</td>
#       <td id="T_74ffb_row6_col3" class="data row6 col3" >362</td>
#       <td id="T_74ffb_row6_col4" class="data row6 col4" >10</td>
#       <td id="T_74ffb_row6_col5" class="data row6 col5" >6.700000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_74ffb_row7_col0" class="data row7 col0" >Mustafizur Rahman</td>
#       <td id="T_74ffb_row7_col1" class="data row7 col1" >Bangladesh</td>
#       <td id="T_74ffb_row7_col2" class="data row7 col2" >61</td>
#       <td id="T_74ffb_row7_col3" class="data row7 col3" >417</td>
#       <td id="T_74ffb_row7_col4" class="data row7 col4" >6</td>
#       <td id="T_74ffb_row7_col5" class="data row7 col5" >6.840000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_74ffb_row8_col0" class="data row8 col0" >DL Vettori</td>
#       <td id="T_74ffb_row8_col1" class="data row8 col1" >New Zealand</td>
#       <td id="T_74ffb_row8_col2" class="data row8 col2" >129</td>
#       <td id="T_74ffb_row8_col3" class="data row8 col3" >888</td>
#       <td id="T_74ffb_row8_col4" class="data row8 col4" >18</td>
#       <td id="T_74ffb_row8_col5" class="data row8 col5" >6.880000</td>
#     </tr>
#     <tr>
#       <th id="T_74ffb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_74ffb_row9_col0" class="data row9 col0" >RE van der Merwe</td>
#       <td id="T_74ffb_row9_col1" class="data row9 col1" >South Africa</td>
#       <td id="T_74ffb_row9_col2" class="data row9 col2" >73</td>
#       <td id="T_74ffb_row9_col3" class="data row9 col3" >503</td>
#       <td id="T_74ffb_row9_col4" class="data row9 col4" >17</td>
#       <td id="T_74ffb_row9_col5" class="data row9 col5" >6.890000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Worst Economy Bowlers

worst_economy=best_economy.tail(10).iloc[::-1,:].reset_index(drop=True)
display(worst_economy.style.background_gradient(subset=["economy"],cmap="YlOrBr_r",low=0.25))
# Out:
# <style type="text/css">
# #T_05886_row0_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_05886_row1_col5 {
#   background-color: #fffbd3;
#   color: #000000;
# }
# #T_05886_row2_col5 {
#   background-color: #ffface;
#   color: #000000;
# }
# #T_05886_row3_col5 {
#   background-color: #fee28e;
#   color: #000000;
# }
# #T_05886_row4_col5 {
#   background-color: #fede86;
#   color: #000000;
# }
# #T_05886_row5_col5 {
#   background-color: #e3660f;
#   color: #f1f1f1;
# }
# #T_05886_row6_col5 {
#   background-color: #d85a09;
#   color: #f1f1f1;
# }
# #T_05886_row7_col5 {
#   background-color: #d55607;
#   color: #f1f1f1;
# }
# #T_05886_row8_col5 {
#   background-color: #c34802;
#   color: #f1f1f1;
# }
# #T_05886_row9_col5 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_05886_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >overs</th>
#       <th class="col_heading level0 col3" >runs</th>
#       <th class="col_heading level0 col4" >extras</th>
#       <th class="col_heading level0 col5" >economy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05886_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05886_row0_col0" class="data row0 col0" >JR Hopes</td>
#       <td id="T_05886_row0_col1" class="data row0 col1" >Australia</td>
#       <td id="T_05886_row0_col2" class="data row0 col2" >60</td>
#       <td id="T_05886_row0_col3" class="data row0 col3" >553</td>
#       <td id="T_05886_row0_col4" class="data row0 col4" >14</td>
#       <td id="T_05886_row0_col5" class="data row0 col5" >9.220000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_05886_row1_col0" class="data row1 col0" >Pankaj Singh</td>
#       <td id="T_05886_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_05886_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_05886_row1_col3" class="data row1 col3" >459</td>
#       <td id="T_05886_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_05886_row1_col5" class="data row1 col5" >9.180000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_05886_row2_col0" class="data row2 col0" >R McLaren</td>
#       <td id="T_05886_row2_col1" class="data row2 col1" >South Africa</td>
#       <td id="T_05886_row2_col2" class="data row2 col2" >59</td>
#       <td id="T_05886_row2_col3" class="data row2 col3" >541</td>
#       <td id="T_05886_row2_col4" class="data row2 col4" >21</td>
#       <td id="T_05886_row2_col5" class="data row2 col5" >9.170000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_05886_row3_col0" class="data row3 col0" >DJ Hussey</td>
#       <td id="T_05886_row3_col1" class="data row3 col1" >Australia</td>
#       <td id="T_05886_row3_col2" class="data row3 col2" >53</td>
#       <td id="T_05886_row3_col3" class="data row3 col3" >479</td>
#       <td id="T_05886_row3_col4" class="data row3 col4" >12</td>
#       <td id="T_05886_row3_col5" class="data row3 col5" >9.040000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_05886_row4_col0" class="data row4 col0" >VRV Singh</td>
#       <td id="T_05886_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_05886_row4_col2" class="data row4 col2" >60</td>
#       <td id="T_05886_row4_col3" class="data row4 col3" >542</td>
#       <td id="T_05886_row4_col4" class="data row4 col4" >11</td>
#       <td id="T_05886_row4_col5" class="data row4 col5" >9.030000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_05886_row5_col0" class="data row5 col0" >Anureet Singh</td>
#       <td id="T_05886_row5_col1" class="data row5 col1" >India</td>
#       <td id="T_05886_row5_col2" class="data row5 col2" >63</td>
#       <td id="T_05886_row5_col3" class="data row5 col3" >552</td>
#       <td id="T_05886_row5_col4" class="data row5 col4" >19</td>
#       <td id="T_05886_row5_col5" class="data row5 col5" >8.760000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_05886_row6_col0" class="data row6 col0" >AB Agarkar</td>
#       <td id="T_05886_row6_col1" class="data row6 col1" >India</td>
#       <td id="T_05886_row6_col2" class="data row6 col2" >131</td>
#       <td id="T_05886_row6_col3" class="data row6 col3" >1144</td>
#       <td id="T_05886_row6_col4" class="data row6 col4" >32</td>
#       <td id="T_05886_row6_col5" class="data row6 col5" >8.730000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_05886_row7_col0" class="data row7 col0" >NLTC Perera</td>
#       <td id="T_05886_row7_col1" class="data row7 col1" >Sri Lanka</td>
#       <td id="T_05886_row7_col2" class="data row7 col2" >117</td>
#       <td id="T_05886_row7_col3" class="data row7 col3" >1020</td>
#       <td id="T_05886_row7_col4" class="data row7 col4" >22</td>
#       <td id="T_05886_row7_col5" class="data row7 col5" >8.720000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_05886_row8_col0" class="data row8 col0" >Mohammed Shami</td>
#       <td id="T_05886_row8_col1" class="data row8 col1" >India</td>
#       <td id="T_05886_row8_col2" class="data row8 col2" >78</td>
#       <td id="T_05886_row8_col3" class="data row8 col3" >677</td>
#       <td id="T_05886_row8_col4" class="data row8 col4" >23</td>
#       <td id="T_05886_row8_col5" class="data row8 col5" >8.680000</td>
#     </tr>
#     <tr>
#       <th id="T_05886_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_05886_row9_col0" class="data row9 col0" >VY Mahesh</td>
#       <td id="T_05886_row9_col1" class="data row9 col1" >India</td>
#       <td id="T_05886_row9_col2" class="data row9 col2" >58</td>
#       <td id="T_05886_row9_col3" class="data row9 col3" >502</td>
#       <td id="T_05886_row9_col4" class="data row9 col4" >24</td>
#       <td id="T_05886_row9_col5" class="data row9 col5" >8.660000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Best Death overs Bowler's in Indian Premier League
#Wickets_rate= average no of wickets ball in an over

sql="""select Player_Name,Country_Name,
       Overs,Runs,Wickets,Economy,
       round(round(Wickets,2)/round(Overs,2),2) as Wicket_rate
       from( select Bowler,count(*) as Overs,sum(runs) as Runs,
             round(round(sum(runs),2)/round(count(*),2),2) as Economy
             from (select a.Bowler,a.Match_Id,
                   sum(coalesce(Runs_Scored,0)+coalesce(Extra_Runs,0)) as runs
                   from Ball_by_Ball a
                   left join Batsman_Scored b 
                   on a.Match_Id=b.Match_Id 
                   and a.Innings_No=b.Innings_No
                   and a.Over_Id=b.Over_Id 
                   and a.Ball_Id=b.Ball_Id
                   left join Extra_Runs c
                   on a.Match_Id=c.Match_Id 
                   and a.Innings_No=c.Innings_No
                   and a.Over_Id=c.Over_Id 
                   and a.Ball_Id=c.Ball_Id
                   where a.Over_Id in (16,17,18,19,20)
                   group by a.Bowler,a.Match_Id,a.Over_Id)
              group by Bowler) a 
        join( select Bowler,sum(Kind_Out) as Wickets
              from Ball_by_Ball a
              join Wicket_Taken b
              on a.Match_Id=b.Match_Id 
              and a.Innings_No=b.Innings_No
              and a.Over_Id=b.Over_Id 
              and a.Ball_Id=b.Ball_Id
              where a.Over_Id in (16,17,18,19,20) and
              Kind_Out in (1,2,4,6,7,8)
              group by a.Bowler) b
        on a.Bowler=b.Bowler
        join( select Player_Id,Player_Name,b.Country_Name, c.Bowling_skill
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Bowling_Style c
              on a.Bowling_skill=c.Bowling_Id) c
      on a.Bowler=c.Player_Id
      where Overs>=50
      order by Economy,Wicket_rate desc; """

death_overs_specialist=pd.read_sql(sql, conn)
subset=["Economy","Wicket_rate"]
death_overs_specialist.head().style.background_gradient(subset=subset,cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_0cb3d_row0_col5, #T_0cb3d_row1_col5, #T_0cb3d_row2_col6 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_0cb3d_row0_col6, #T_0cb3d_row4_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_0cb3d_row1_col6 {
#   background-color: #fee28e;
#   color: #000000;
# }
# #T_0cb3d_row2_col5 {
#   background-color: #feeca4;
#   color: #000000;
# }
# #T_0cb3d_row3_col5 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_0cb3d_row3_col6 {
#   background-color: #dc5e0b;
#   color: #f1f1f1;
# }
# #T_0cb3d_row4_col6 {
#   background-color: #fff8c4;
#   color: #000000;
# }
# </style>
# <table id="T_0cb3d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Overs</th>
#       <th class="col_heading level0 col3" >Runs</th>
#       <th class="col_heading level0 col4" >Wickets</th>
#       <th class="col_heading level0 col5" >Economy</th>
#       <th class="col_heading level0 col6" >Wicket_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cb3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cb3d_row0_col0" class="data row0 col0" >SP Narine</td>
#       <td id="T_0cb3d_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_0cb3d_row0_col2" class="data row0 col2" >98</td>
#       <td id="T_0cb3d_row0_col3" class="data row0 col3" >718</td>
#       <td id="T_0cb3d_row0_col4" class="data row0 col4" >130</td>
#       <td id="T_0cb3d_row0_col5" class="data row0 col5" >7.330000</td>
#       <td id="T_0cb3d_row0_col6" class="data row0 col6" >1.330000</td>
#     </tr>
#     <tr>
#       <th id="T_0cb3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cb3d_row1_col0" class="data row1 col0" >SL Malinga</td>
#       <td id="T_0cb3d_row1_col1" class="data row1 col1" >Sri Lanka</td>
#       <td id="T_0cb3d_row1_col2" class="data row1 col2" >160</td>
#       <td id="T_0cb3d_row1_col3" class="data row1 col3" >1172</td>
#       <td id="T_0cb3d_row1_col4" class="data row1 col4" >180</td>
#       <td id="T_0cb3d_row1_col5" class="data row1 col5" >7.330000</td>
#       <td id="T_0cb3d_row1_col6" class="data row1 col6" >1.130000</td>
#     </tr>
#     <tr>
#       <th id="T_0cb3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0cb3d_row2_col0" class="data row2 col0" >R Ashwin</td>
#       <td id="T_0cb3d_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_0cb3d_row2_col2" class="data row2 col2" >61</td>
#       <td id="T_0cb3d_row2_col3" class="data row2 col3" >479</td>
#       <td id="T_0cb3d_row2_col4" class="data row2 col4" >43</td>
#       <td id="T_0cb3d_row2_col5" class="data row2 col5" >7.850000</td>
#       <td id="T_0cb3d_row2_col6" class="data row2 col6" >0.700000</td>
#     </tr>
#     <tr>
#       <th id="T_0cb3d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0cb3d_row3_col0" class="data row3 col0" >DW Steyn</td>
#       <td id="T_0cb3d_row3_col1" class="data row3 col1" >South Africa</td>
#       <td id="T_0cb3d_row3_col2" class="data row3 col2" >101</td>
#       <td id="T_0cb3d_row3_col3" class="data row3 col3" >806</td>
#       <td id="T_0cb3d_row3_col4" class="data row3 col4" >80</td>
#       <td id="T_0cb3d_row3_col5" class="data row3 col5" >7.980000</td>
#       <td id="T_0cb3d_row3_col6" class="data row3 col6" >0.790000</td>
#     </tr>
#     <tr>
#       <th id="T_0cb3d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0cb3d_row4_col0" class="data row4 col0" >PP Chawla</td>
#       <td id="T_0cb3d_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_0cb3d_row4_col2" class="data row4 col2" >56</td>
#       <td id="T_0cb3d_row4_col3" class="data row4 col3" >449</td>
#       <td id="T_0cb3d_row4_col4" class="data row4 col4" >70</td>
#       <td id="T_0cb3d_row4_col5" class="data row4 col5" >8.020000</td>
#       <td id="T_0cb3d_row4_col6" class="data row4 col6" >1.250000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Poor Death overs Bowler's in Indian Premier League
subset=["Economy","Wicket_rate"]
death_overs_poor=death_overs_specialist.tail().iloc[::-1,:].reset_index(drop=True)
death_overs_poor.style.background_gradient(subset=subset,cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_ed97f_row0_col5, #T_ed97f_row2_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_ed97f_row0_col6, #T_ed97f_row4_col5 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_ed97f_row1_col5, #T_ed97f_row2_col5 {
#   background-color: #ec7014;
#   color: #f1f1f1;
# }
# #T_ed97f_row1_col6 {
#   background-color: #fea030;
#   color: #000000;
# }
# #T_ed97f_row3_col5 {
#   background-color: #e66a11;
#   color: #f1f1f1;
# }
# #T_ed97f_row3_col6 {
#   background-color: #fec857;
#   color: #000000;
# }
# #T_ed97f_row4_col6 {
#   background-color: #fff7be;
#   color: #000000;
# }
# </style>
# <table id="T_ed97f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Overs</th>
#       <th class="col_heading level0 col3" >Runs</th>
#       <th class="col_heading level0 col4" >Wickets</th>
#       <th class="col_heading level0 col5" >Economy</th>
#       <th class="col_heading level0 col6" >Wicket_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed97f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed97f_row0_col0" class="data row0 col0" >I Sharma</td>
#       <td id="T_ed97f_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_ed97f_row0_col2" class="data row0 col2" >56</td>
#       <td id="T_ed97f_row0_col3" class="data row0 col3" >611</td>
#       <td id="T_ed97f_row0_col4" class="data row0 col4" >16</td>
#       <td id="T_ed97f_row0_col5" class="data row0 col5" >10.910000</td>
#       <td id="T_ed97f_row0_col6" class="data row0 col6" >0.290000</td>
#     </tr>
#     <tr>
#       <th id="T_ed97f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed97f_row1_col0" class="data row1 col0" >AB Dinda</td>
#       <td id="T_ed97f_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_ed97f_row1_col2" class="data row1 col2" >67</td>
#       <td id="T_ed97f_row1_col3" class="data row1 col3" >698</td>
#       <td id="T_ed97f_row1_col4" class="data row1 col4" >30</td>
#       <td id="T_ed97f_row1_col5" class="data row1 col5" >10.420000</td>
#       <td id="T_ed97f_row1_col6" class="data row1 col6" >0.450000</td>
#     </tr>
#     <tr>
#       <th id="T_ed97f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed97f_row2_col0" class="data row2 col0" >MM Patel</td>
#       <td id="T_ed97f_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_ed97f_row2_col2" class="data row2 col2" >52</td>
#       <td id="T_ed97f_row2_col3" class="data row2 col3" >542</td>
#       <td id="T_ed97f_row2_col4" class="data row2 col4" >36</td>
#       <td id="T_ed97f_row2_col5" class="data row2 col5" >10.420000</td>
#       <td id="T_ed97f_row2_col6" class="data row2 col6" >0.690000</td>
#     </tr>
#     <tr>
#       <th id="T_ed97f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed97f_row3_col0" class="data row3 col0" >P Kumar</td>
#       <td id="T_ed97f_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_ed97f_row3_col2" class="data row3 col2" >98</td>
#       <td id="T_ed97f_row3_col3" class="data row3 col3" >1019</td>
#       <td id="T_ed97f_row3_col4" class="data row3 col4" >50</td>
#       <td id="T_ed97f_row3_col5" class="data row3 col5" >10.400000</td>
#       <td id="T_ed97f_row3_col6" class="data row3 col6" >0.510000</td>
#     </tr>
#     <tr>
#       <th id="T_ed97f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed97f_row4_col0" class="data row4 col0" >JH Kallis</td>
#       <td id="T_ed97f_row4_col1" class="data row4 col1" >South Africa</td>
#       <td id="T_ed97f_row4_col2" class="data row4 col2" >60</td>
#       <td id="T_ed97f_row4_col3" class="data row4 col3" >617</td>
#       <td id="T_ed97f_row4_col4" class="data row4 col4" >38</td>
#       <td id="T_ed97f_row4_col5" class="data row4 col5" >10.280000</td>
#       <td id="T_ed97f_row4_col6" class="data row4 col6" >0.630000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Best powerplay overs Bowler's in Indian Premier League
#Wickets_rate= average no of wickets ball in an over

sql="""select Player_Name,Country_Name,
       Overs,Runs,Wickets,Economy,
       round(round(Wickets,2)/round(Overs,2),2) as Wicket_rate
       from( select Bowler,count(*) as Overs,sum(runs) as Runs,
             round(round(sum(runs),2)/round(count(*),2),2) as Economy
             from (select a.Bowler,a.Match_Id,
                   sum(coalesce(Runs_Scored,0)+coalesce(Extra_Runs,0)) as runs
                   from Ball_by_Ball a
                   left join Batsman_Scored b 
                   on a.Match_Id=b.Match_Id 
                   and a.Innings_No=b.Innings_No
                   and a.Over_Id=b.Over_Id 
                   and a.Ball_Id=b.Ball_Id
                   left join Extra_Runs c
                   on a.Match_Id=c.Match_Id 
                   and a.Innings_No=c.Innings_No
                   and a.Over_Id=c.Over_Id 
                   and a.Ball_Id=c.Ball_Id
                   where a.Over_Id in (1,2,3,4,5,6)
                   group by a.Bowler,a.Match_Id,a.Over_Id)
              group by Bowler) a 
        join( select Bowler,sum(Kind_Out) as Wickets
              from Ball_by_Ball a
              join Wicket_Taken b
              on a.Match_Id=b.Match_Id 
              and a.Innings_No=b.Innings_No
              and a.Over_Id=b.Over_Id 
              and a.Ball_Id=b.Ball_Id
              where a.Over_Id in (1,2,3,4,5,6) and
              Kind_Out in (1,2,4,6,7,8)
              group by a.Bowler) b
        on a.Bowler=b.Bowler
        join( select Player_Id,Player_Name,b.Country_Name, c.Bowling_skill
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Bowling_Style c
              on a.Bowling_skill=c.Bowling_Id) c
      on a.Bowler=c.Player_Id
      where Overs>=50
      order by Economy,Wicket_rate desc; """

powerplay_overs_specialist=pd.read_sql(sql, conn)
subset=["Economy","Wicket_rate"]
powerplay_overs_specialist.head().style.background_gradient(subset=subset,cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_a0e9c_row0_col5, #T_a0e9c_row4_col6 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_a0e9c_row0_col6 {
#   background-color: #f17c1a;
#   color: #f1f1f1;
# }
# #T_a0e9c_row1_col5 {
#   background-color: #fee390;
#   color: #000000;
# }
# #T_a0e9c_row1_col6 {
#   background-color: #d75908;
#   color: #f1f1f1;
# }
# #T_a0e9c_row2_col5 {
#   background-color: #fff0ad;
#   color: #000000;
# }
# #T_a0e9c_row2_col6, #T_a0e9c_row4_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a0e9c_row3_col5 {
#   background-color: #fff4b6;
#   color: #000000;
# }
# #T_a0e9c_row3_col6 {
#   background-color: #fecf67;
#   color: #000000;
# }
# </style>
# <table id="T_a0e9c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Overs</th>
#       <th class="col_heading level0 col3" >Runs</th>
#       <th class="col_heading level0 col4" >Wickets</th>
#       <th class="col_heading level0 col5" >Economy</th>
#       <th class="col_heading level0 col6" >Wicket_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0e9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0e9c_row0_col0" class="data row0 col0" >SP Narine</td>
#       <td id="T_a0e9c_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_a0e9c_row0_col2" class="data row0 col2" >64</td>
#       <td id="T_a0e9c_row0_col3" class="data row0 col3" >354</td>
#       <td id="T_a0e9c_row0_col4" class="data row0 col4" >26</td>
#       <td id="T_a0e9c_row0_col5" class="data row0 col5" >5.530000</td>
#       <td id="T_a0e9c_row0_col6" class="data row0 col6" >0.410000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e9c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0e9c_row1_col0" class="data row1 col0" >SL Malinga</td>
#       <td id="T_a0e9c_row1_col1" class="data row1 col1" >Sri Lanka</td>
#       <td id="T_a0e9c_row1_col2" class="data row1 col2" >147</td>
#       <td id="T_a0e9c_row1_col3" class="data row1 col3" >902</td>
#       <td id="T_a0e9c_row1_col4" class="data row1 col4" >53</td>
#       <td id="T_a0e9c_row1_col5" class="data row1 col5" >6.140000</td>
#       <td id="T_a0e9c_row1_col6" class="data row1 col6" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e9c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0e9c_row2_col0" class="data row2 col0" >R Ashwin</td>
#       <td id="T_a0e9c_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_a0e9c_row2_col2" class="data row2 col2" >117</td>
#       <td id="T_a0e9c_row2_col3" class="data row2 col3" >729</td>
#       <td id="T_a0e9c_row2_col4" class="data row2 col4" >77</td>
#       <td id="T_a0e9c_row2_col5" class="data row2 col5" >6.230000</td>
#       <td id="T_a0e9c_row2_col6" class="data row2 col6" >0.660000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e9c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0e9c_row3_col0" class="data row3 col0" >B Kumar</td>
#       <td id="T_a0e9c_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_a0e9c_row3_col2" class="data row3 col2" >151</td>
#       <td id="T_a0e9c_row3_col3" class="data row3 col3" >945</td>
#       <td id="T_a0e9c_row3_col4" class="data row3 col4" >78</td>
#       <td id="T_a0e9c_row3_col5" class="data row3 col5" >6.260000</td>
#       <td id="T_a0e9c_row3_col6" class="data row3 col6" >0.520000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e9c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a0e9c_row4_col0" class="data row4 col0" >DW Steyn</td>
#       <td id="T_a0e9c_row4_col1" class="data row4 col1" >South Africa</td>
#       <td id="T_a0e9c_row4_col2" class="data row4 col2" >177</td>
#       <td id="T_a0e9c_row4_col3" class="data row4 col3" >1136</td>
#       <td id="T_a0e9c_row4_col4" class="data row4 col4" >56</td>
#       <td id="T_a0e9c_row4_col5" class="data row4 col5" >6.420000</td>
#       <td id="T_a0e9c_row4_col6" class="data row4 col6" >0.320000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Poor Powerplay overs Bowler's in Indian Premier League
subset=["Economy","Wicket_rate"]
powerplay_overs_poor=powerplay_overs_specialist.tail().iloc[::-1,:].reset_index(drop=True)
powerplay_overs_poor.style.background_gradient(subset=subset,cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_697b5_row0_col5, #T_697b5_row1_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_697b5_row0_col6 {
#   background-color: #fedf88;
#   color: #000000;
# }
# #T_697b5_row1_col5 {
#   background-color: #fff7bd;
#   color: #000000;
# }
# #T_697b5_row2_col5, #T_697b5_row3_col5 {
#   background-color: #be4503;
#   color: #f1f1f1;
# }
# #T_697b5_row2_col6 {
#   background-color: #fea231;
#   color: #000000;
# }
# #T_697b5_row3_col6 {
#   background-color: #fed069;
#   color: #000000;
# }
# #T_697b5_row4_col5, #T_697b5_row4_col6 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_697b5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Overs</th>
#       <th class="col_heading level0 col3" >Runs</th>
#       <th class="col_heading level0 col4" >Wickets</th>
#       <th class="col_heading level0 col5" >Economy</th>
#       <th class="col_heading level0 col6" >Wicket_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_697b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_697b5_row0_col0" class="data row0 col0" >MS Gony</td>
#       <td id="T_697b5_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_697b5_row0_col2" class="data row0 col2" >80</td>
#       <td id="T_697b5_row0_col3" class="data row0 col3" >705</td>
#       <td id="T_697b5_row0_col4" class="data row0 col4" >30</td>
#       <td id="T_697b5_row0_col5" class="data row0 col5" >8.810000</td>
#       <td id="T_697b5_row0_col6" class="data row0 col6" >0.380000</td>
#     </tr>
#     <tr>
#       <th id="T_697b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_697b5_row1_col0" class="data row1 col0" >JA Morkel</td>
#       <td id="T_697b5_row1_col1" class="data row1 col1" >South Africa</td>
#       <td id="T_697b5_row1_col2" class="data row1 col2" >150</td>
#       <td id="T_697b5_row1_col3" class="data row1 col3" >1300</td>
#       <td id="T_697b5_row1_col4" class="data row1 col4" >71</td>
#       <td id="T_697b5_row1_col5" class="data row1 col5" >8.670000</td>
#       <td id="T_697b5_row1_col6" class="data row1 col6" >0.470000</td>
#     </tr>
#     <tr>
#       <th id="T_697b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_697b5_row2_col0" class="data row2 col0" >UT Yadav</td>
#       <td id="T_697b5_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_697b5_row2_col2" class="data row2 col2" >98</td>
#       <td id="T_697b5_row2_col3" class="data row2 col3" >776</td>
#       <td id="T_697b5_row2_col4" class="data row2 col4" >30</td>
#       <td id="T_697b5_row2_col5" class="data row2 col5" >7.920000</td>
#       <td id="T_697b5_row2_col6" class="data row2 col6" >0.310000</td>
#     </tr>
#     <tr>
#       <th id="T_697b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_697b5_row3_col0" class="data row3 col0" >CH Morris</td>
#       <td id="T_697b5_row3_col1" class="data row3 col1" >South Africa</td>
#       <td id="T_697b5_row3_col2" class="data row3 col2" >53</td>
#       <td id="T_697b5_row3_col3" class="data row3 col3" >420</td>
#       <td id="T_697b5_row3_col4" class="data row3 col4" >19</td>
#       <td id="T_697b5_row3_col5" class="data row3 col5" >7.920000</td>
#       <td id="T_697b5_row3_col6" class="data row3 col6" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_697b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_697b5_row4_col0" class="data row4 col0" >MJ McClenaghan</td>
#       <td id="T_697b5_row4_col1" class="data row4 col1" >New Zealand</td>
#       <td id="T_697b5_row4_col2" class="data row4 col2" >51</td>
#       <td id="T_697b5_row4_col3" class="data row4 col3" >403</td>
#       <td id="T_697b5_row4_col4" class="data row4 col4" >10</td>
#       <td id="T_697b5_row4_col5" class="data row4 col5" >7.900000</td>
#       <td id="T_697b5_row4_col6" class="data row4 col6" >0.200000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Best Middle overs Bowler's in Indian Premier League
#Wickets_rate= average no of wickets ball in an over

sql="""select Player_Name,Country_Name,
       Overs,Runs,Wickets,Economy,
       round(round(Wickets,2)/round(Overs,2),2) as Wicket_rate
       from( select Bowler,count(*) as Overs,sum(runs) as Runs,
             round(round(sum(runs),2)/round(count(*),2),2) as Economy
             from (select a.Bowler,a.Match_Id,
                   sum(coalesce(Runs_Scored,0)+coalesce(Extra_Runs,0)) as runs
                   from Ball_by_Ball a
                   left join Batsman_Scored b 
                   on a.Match_Id=b.Match_Id 
                   and a.Innings_No=b.Innings_No
                   and a.Over_Id=b.Over_Id 
                   and a.Ball_Id=b.Ball_Id
                   left join Extra_Runs c
                   on a.Match_Id=c.Match_Id 
                   and a.Innings_No=c.Innings_No
                   and a.Over_Id=c.Over_Id 
                   and a.Ball_Id=c.Ball_Id
                   where a.Over_Id in (7,8,9,10,11,12,13,14,15)
                   group by a.Bowler,a.Match_Id,a.Over_Id)
              group by Bowler) a 
        join( select Bowler,sum(Kind_Out) as Wickets
              from Ball_by_Ball a
              join Wicket_Taken b
              on a.Match_Id=b.Match_Id 
              and a.Innings_No=b.Innings_No
              and a.Over_Id=b.Over_Id 
              and a.Ball_Id=b.Ball_Id
              where a.Over_Id in (1,2,3,4,5,6) and
              Kind_Out in (1,2,4,6,7,8)
              group by a.Bowler) b
        on a.Bowler=b.Bowler
        join( select Player_Id,Player_Name,b.Country_Name, c.Bowling_skill
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Bowling_Style c
              on a.Bowling_skill=c.Bowling_Id) c
      on a.Bowler=c.Player_Id
      where Overs>=50
      order by Economy,Wicket_rate desc; """

middle_overs_specialist=pd.read_sql(sql, conn)
subset=["Economy","Wicket_rate"]
middle_overs_specialist.head().style.background_gradient(subset=subset,cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_5fefd_row0_col5, #T_5fefd_row2_col6 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_5fefd_row0_col6 {
#   background-color: #df620d;
#   color: #f1f1f1;
# }
# #T_5fefd_row1_col5 {
#   background-color: #cc4c02;
#   color: #f1f1f1;
# }
# #T_5fefd_row1_col6, #T_5fefd_row4_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_5fefd_row2_col5 {
#   background-color: #feb541;
#   color: #000000;
# }
# #T_5fefd_row3_col5 {
#   background-color: #fff8c4;
#   color: #000000;
# }
# #T_5fefd_row3_col6 {
#   background-color: #dd5f0c;
#   color: #f1f1f1;
# }
# #T_5fefd_row4_col6 {
#   background-color: #e56910;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5fefd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Overs</th>
#       <th class="col_heading level0 col3" >Runs</th>
#       <th class="col_heading level0 col4" >Wickets</th>
#       <th class="col_heading level0 col5" >Economy</th>
#       <th class="col_heading level0 col6" >Wicket_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fefd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5fefd_row0_col0" class="data row0 col0" >SP Narine</td>
#       <td id="T_5fefd_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_5fefd_row0_col2" class="data row0 col2" >102</td>
#       <td id="T_5fefd_row0_col3" class="data row0 col3" >601</td>
#       <td id="T_5fefd_row0_col4" class="data row0 col4" >26</td>
#       <td id="T_5fefd_row0_col5" class="data row0 col5" >5.890000</td>
#       <td id="T_5fefd_row0_col6" class="data row0 col6" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_5fefd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5fefd_row1_col0" class="data row1 col0" >MM Patel</td>
#       <td id="T_5fefd_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_5fefd_row1_col2" class="data row1 col2" >60</td>
#       <td id="T_5fefd_row1_col3" class="data row1 col3" >356</td>
#       <td id="T_5fefd_row1_col4" class="data row1 col4" >53</td>
#       <td id="T_5fefd_row1_col5" class="data row1 col5" >5.930000</td>
#       <td id="T_5fefd_row1_col6" class="data row1 col6" >0.880000</td>
#     </tr>
#     <tr>
#       <th id="T_5fefd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5fefd_row2_col0" class="data row2 col0" >RE van der Merwe</td>
#       <td id="T_5fefd_row2_col1" class="data row2 col1" >South Africa</td>
#       <td id="T_5fefd_row2_col2" class="data row2 col2" >52</td>
#       <td id="T_5fefd_row2_col3" class="data row2 col3" >322</td>
#       <td id="T_5fefd_row2_col4" class="data row2 col4" >7</td>
#       <td id="T_5fefd_row2_col5" class="data row2 col5" >6.190000</td>
#       <td id="T_5fefd_row2_col6" class="data row2 col6" >0.130000</td>
#     </tr>
#     <tr>
#       <th id="T_5fefd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5fefd_row3_col0" class="data row3 col0" >J Botha</td>
#       <td id="T_5fefd_row3_col1" class="data row3 col1" >South Africa</td>
#       <td id="T_5fefd_row3_col2" class="data row3 col2" >66</td>
#       <td id="T_5fefd_row3_col3" class="data row3 col3" >425</td>
#       <td id="T_5fefd_row3_col4" class="data row3 col4" >16</td>
#       <td id="T_5fefd_row3_col5" class="data row3 col5" >6.440000</td>
#       <td id="T_5fefd_row3_col6" class="data row3 col6" >0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_5fefd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5fefd_row4_col0" class="data row4 col0" >Shakib Al Hasan</td>
#       <td id="T_5fefd_row4_col1" class="data row4 col1" >Bangladesh</td>
#       <td id="T_5fefd_row4_col2" class="data row4 col2" >79</td>
#       <td id="T_5fefd_row4_col3" class="data row4 col3" >515</td>
#       <td id="T_5fefd_row4_col4" class="data row4 col4" >21</td>
#       <td id="T_5fefd_row4_col5" class="data row4 col5" >6.520000</td>
#       <td id="T_5fefd_row4_col6" class="data row4 col6" >0.270000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Best Bowlers in IPL 

sql=""" select Player_Name,Country_Name,
        Matches,Runs,Wickets,Economy,Best
        from(select Bowler,sum(coalesce(Extra_Runs,0)+Runs_Scored) as Runs,
             count(*)/6 as overs,
             round(round(sum(coalesce(Extra_Runs,0)+Runs_Scored),2)/round(count(*)/6,2),2) as Economy
             from Ball_by_Ball a
             left join Batsman_Scored b
             on a.Match_Id=b.Match_Id
             and a.Innings_No=b.Innings_No
             and a.Over_Id=b.Over_Id
             and a.Ball_Id=b.Ball_Id
             left join Extra_Runs c
             on a.Match_Id=c.Match_Id
             and a.Innings_No=c.Innings_No
             and a.Over_Id=c.Over_Id
             and a.Ball_Id=c.Ball_Id
             group by Bowler
             having overs>=50) a 
        join( select Bowler,count(Kind_Out) as Wickets
              from Ball_by_Ball a
              join Wicket_Taken b
              on a.Match_Id=b.Match_Id 
              and a.Innings_No=b.Innings_No
              and a.Over_Id=b.Over_Id 
              and a.Ball_Id=b.Ball_Id
              where Kind_Out in (1,2,4,6,7,8)
              group by Bowler) b
        on a.Bowler=b.Bowler
        join( select a.Bowler,max(Wickets)||"-"||runs as Best
              from( select a.Bowler,a.Match_Id,count(Kind_Out) as Wickets
                    from Ball_by_Ball a
                    join Wicket_Taken b
                    on a.Match_Id=b.Match_Id 
                    and a.Innings_No=b.Innings_No
                    and a.Over_Id=b.Over_Id 
                    and a.Ball_Id=b.Ball_Id
                    where Kind_Out in (1,2,4,6,7,8)
                    group by a.Bowler,a.Match_Id) a
              join( select a.Bowler,a.Match_Id,
                    sum(coalesce(Runs_Scored,0)+coalesce(Extra_Runs,0)) as runs
                    from Ball_by_Ball a
                    left join Batsman_Scored b 
                    on a.Match_Id=b.Match_Id 
                    and a.Innings_No=b.Innings_No
                    and a.Over_Id=b.Over_Id 
                    and a.Ball_Id=b.Ball_Id
                    left join Extra_Runs c
                    on a.Match_Id=c.Match_Id 
                    and a.Innings_No=c.Innings_No
                    and a.Over_Id=c.Over_Id 
                    and a.Ball_Id=c.Ball_Id
                    group by a.Bowler,a.Match_Id) b
              on a.Bowler=b.Bowler
              group by a.Bowler) c
        on a.Bowler=c.Bowler
        join( select Bowler,count (distinct Match_Id)as Matches
              from Ball_by_Ball
              group by Bowler) d
        on a.Bowler=d.Bowler
        join (select Player_Id,Player_Name,b.Bowling_skill,c.Country_Name
              from Player a
              join Bowling_Style b
              on a.Bowling_skill=b.Bowling_Id
              join Country c
              on a.Country_Name=c.Country_Id) e
        on a.Bowler=e.Player_Id
        order by Economy,Wickets; """

best_bowler=pd.read_sql(sql, conn)
subset=["Runs","Economy"]
best_bowler.head().style.background_gradient(subset=subset,cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_14bab_row0_col3, #T_14bab_row0_col5 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_14bab_row1_col3 {
#   background-color: #fffcd4;
#   color: #000000;
# }
# #T_14bab_row1_col5 {
#   background-color: #e86c12;
#   color: #f1f1f1;
# }
# #T_14bab_row2_col3, #T_14bab_row4_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_14bab_row2_col5 {
#   background-color: #f3801c;
#   color: #f1f1f1;
# }
# #T_14bab_row3_col3 {
#   background-color: #fee79a;
#   color: #000000;
# }
# #T_14bab_row3_col5 {
#   background-color: #feb643;
#   color: #000000;
# }
# #T_14bab_row4_col3 {
#   background-color: #cb4b02;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_14bab_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Matches</th>
#       <th class="col_heading level0 col3" >Runs</th>
#       <th class="col_heading level0 col4" >Wickets</th>
#       <th class="col_heading level0 col5" >Economy</th>
#       <th class="col_heading level0 col6" >Best</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14bab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14bab_row0_col0" class="data row0 col0" >SP Narine</td>
#       <td id="T_14bab_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_14bab_row0_col2" class="data row0 col2" >66</td>
#       <td id="T_14bab_row0_col3" class="data row0 col3" >1657</td>
#       <td id="T_14bab_row0_col4" class="data row0 col4" >85</td>
#       <td id="T_14bab_row0_col5" class="data row0 col5" >6.250000</td>
#       <td id="T_14bab_row0_col6" class="data row0 col6" >5-11</td>
#     </tr>
#     <tr>
#       <th id="T_14bab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14bab_row1_col0" class="data row1 col0" >R Ashwin</td>
#       <td id="T_14bab_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_14bab_row1_col2" class="data row1 col2" >108</td>
#       <td id="T_14bab_row1_col3" class="data row1 col3" >2475</td>
#       <td id="T_14bab_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_14bab_row1_col5" class="data row1 col5" >6.300000</td>
#       <td id="T_14bab_row1_col6" class="data row1 col6" >4-3</td>
#     </tr>
#     <tr>
#       <th id="T_14bab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14bab_row2_col0" class="data row2 col0" >SL Malinga</td>
#       <td id="T_14bab_row2_col1" class="data row2 col1" >Sri Lanka</td>
#       <td id="T_14bab_row2_col2" class="data row2 col2" >98</td>
#       <td id="T_14bab_row2_col3" class="data row2 col3" >2534</td>
#       <td id="T_14bab_row2_col4" class="data row2 col4" >143</td>
#       <td id="T_14bab_row2_col5" class="data row2 col5" >6.320000</td>
#       <td id="T_14bab_row2_col6" class="data row2 col6" >5-6</td>
#     </tr>
#     <tr>
#       <th id="T_14bab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14bab_row3_col0" class="data row3 col0" >DW Steyn</td>
#       <td id="T_14bab_row3_col1" class="data row3 col1" >South Africa</td>
#       <td id="T_14bab_row3_col2" class="data row3 col2" >90</td>
#       <td id="T_14bab_row3_col3" class="data row3 col3" >2287</td>
#       <td id="T_14bab_row3_col4" class="data row3 col4" >92</td>
#       <td id="T_14bab_row3_col5" class="data row3 col5" >6.370000</td>
#       <td id="T_14bab_row3_col6" class="data row3 col6" >3-6</td>
#     </tr>
#     <tr>
#       <th id="T_14bab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14bab_row4_col0" class="data row4 col0" >M Muralitharan</td>
#       <td id="T_14bab_row4_col1" class="data row4 col1" >Sri Lanka</td>
#       <td id="T_14bab_row4_col2" class="data row4 col2" >66</td>
#       <td id="T_14bab_row4_col3" class="data row4 col3" >1709</td>
#       <td id="T_14bab_row4_col4" class="data row4 col4" >64</td>
#       <td id="T_14bab_row4_col5" class="data row4 col5" >6.500000</td>
#       <td id="T_14bab_row4_col6" class="data row4 col6" >4-8</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Worst Bowlers in IPL

subset=["Runs","Economy"]
worst_bowler=best_bowler.tail().iloc[::-1,:].reset_index(drop=True)
worst_bowler.style.background_gradient(subset=subset,cmap="YlOrBr_r",low=0.25)
# Out:
# <style type="text/css">
# #T_ad6b7_row0_col3, #T_ad6b7_row0_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_ad6b7_row1_col3 {
#   background-color: #ea6e13;
#   color: #f1f1f1;
# }
# #T_ad6b7_row1_col5 {
#   background-color: #fff6b9;
#   color: #000000;
# }
# #T_ad6b7_row2_col3, #T_ad6b7_row4_col5 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_ad6b7_row2_col5 {
#   background-color: #fed471;
#   color: #000000;
# }
# #T_ad6b7_row3_col3 {
#   background-color: #c44802;
#   color: #f1f1f1;
# }
# #T_ad6b7_row3_col5 {
#   background-color: #c94b02;
#   color: #f1f1f1;
# }
# #T_ad6b7_row4_col3 {
#   background-color: #fff9c7;
#   color: #000000;
# }
# </style>
# <table id="T_ad6b7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Matches</th>
#       <th class="col_heading level0 col3" >Runs</th>
#       <th class="col_heading level0 col4" >Wickets</th>
#       <th class="col_heading level0 col5" >Economy</th>
#       <th class="col_heading level0 col6" >Best</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad6b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad6b7_row0_col0" class="data row0 col0" >JR Hopes</td>
#       <td id="T_ad6b7_row0_col1" class="data row0 col1" >Australia</td>
#       <td id="T_ad6b7_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_ad6b7_row0_col3" class="data row0 col3" >553</td>
#       <td id="T_ad6b7_row0_col4" class="data row0 col4" >14</td>
#       <td id="T_ad6b7_row0_col5" class="data row0 col5" >9.070000</td>
#       <td id="T_ad6b7_row0_col6" class="data row0 col6" >2-3</td>
#     </tr>
#     <tr>
#       <th id="T_ad6b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad6b7_row1_col0" class="data row1 col0" >DJ Hussey</td>
#       <td id="T_ad6b7_row1_col1" class="data row1 col1" >Australia</td>
#       <td id="T_ad6b7_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_ad6b7_row1_col3" class="data row1 col3" >479</td>
#       <td id="T_ad6b7_row1_col4" class="data row1 col4" >8</td>
#       <td id="T_ad6b7_row1_col5" class="data row1 col5" >9.040000</td>
#       <td id="T_ad6b7_row1_col6" class="data row1 col6" >2-2</td>
#     </tr>
#     <tr>
#       <th id="T_ad6b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad6b7_row2_col0" class="data row2 col0" >Pankaj Singh</td>
#       <td id="T_ad6b7_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_ad6b7_row2_col2" class="data row2 col2" >17</td>
#       <td id="T_ad6b7_row2_col3" class="data row2 col3" >459</td>
#       <td id="T_ad6b7_row2_col4" class="data row2 col4" >11</td>
#       <td id="T_ad6b7_row2_col5" class="data row2 col5" >9.000000</td>
#       <td id="T_ad6b7_row2_col6" class="data row2 col6" >2-12</td>
#     </tr>
#     <tr>
#       <th id="T_ad6b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad6b7_row3_col0" class="data row3 col0" >A Mithun</td>
#       <td id="T_ad6b7_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_ad6b7_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_ad6b7_row3_col3" class="data row3 col3" >463</td>
#       <td id="T_ad6b7_row3_col4" class="data row3 col4" >7</td>
#       <td id="T_ad6b7_row3_col5" class="data row3 col5" >8.900000</td>
#       <td id="T_ad6b7_row3_col6" class="data row3 col6" >2-14</td>
#     </tr>
#     <tr>
#       <th id="T_ad6b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad6b7_row4_col0" class="data row4 col0" >VRV Singh</td>
#       <td id="T_ad6b7_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_ad6b7_row4_col2" class="data row4 col2" >18</td>
#       <td id="T_ad6b7_row4_col3" class="data row4 col3" >542</td>
#       <td id="T_ad6b7_row4_col4" class="data row4 col4" >12</td>
#       <td id="T_ad6b7_row4_col5" class="data row4 col5" >8.890000</td>
#       <td id="T_ad6b7_row4_col6" class="data row4 col6" >3-5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Batting Statistics

# %%
#Batsmens who have faced most deliveries

sql="""SELECT Player_Name,c.Country_Name,d.Batting_hand,count(*) as Deliveries
       FROM Ball_by_Ball a
       join Player b
       on a.Striker==b.Player_Id
       join Country c
       on b.Country_Name==c.Country_Id
       join Batting_Style d
       on b.Batting_hand==d.Batting_Id
       group by Striker
       order by Deliveries desc ;"""

batters=pd.read_sql(sql, conn)
batters.head().style.background_gradient(subset=["Deliveries"],low=0.55)
# Out:
# <style type="text/css">
# #T_072ba_row0_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_072ba_row1_col3 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_072ba_row2_col3 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_072ba_row3_col3 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_072ba_row4_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# </style>
# <table id="T_072ba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Batting_hand</th>
#       <th class="col_heading level0 col3" >Deliveries</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_072ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_072ba_row0_col0" class="data row0 col0" >V Kohli</td>
#       <td id="T_072ba_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_072ba_row0_col2" class="data row0 col2" >Right-hand bat</td>
#       <td id="T_072ba_row0_col3" class="data row0 col3" >3237</td>
#     </tr>
#     <tr>
#       <th id="T_072ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_072ba_row1_col0" class="data row1 col0" >SK Raina</td>
#       <td id="T_072ba_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_072ba_row1_col2" class="data row1 col2" >Left-hand bat</td>
#       <td id="T_072ba_row1_col3" class="data row1 col3" >3059</td>
#     </tr>
#     <tr>
#       <th id="T_072ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_072ba_row2_col0" class="data row2 col0" >G Gambhir</td>
#       <td id="T_072ba_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_072ba_row2_col2" class="data row2 col2" >Left-hand bat</td>
#       <td id="T_072ba_row2_col3" class="data row2 col3" >3028</td>
#     </tr>
#     <tr>
#       <th id="T_072ba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_072ba_row3_col0" class="data row3 col0" >RG Sharma</td>
#       <td id="T_072ba_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_072ba_row3_col2" class="data row3 col2" >Right-hand bat</td>
#       <td id="T_072ba_row3_col3" class="data row3 col3" >2996</td>
#     </tr>
#     <tr>
#       <th id="T_072ba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_072ba_row4_col0" class="data row4 col0" >RV Uthappa</td>
#       <td id="T_072ba_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_072ba_row4_col2" class="data row4 col2" >Right-hand bat</td>
#       <td id="T_072ba_row4_col3" class="data row4 col3" >2721</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highest run scored by a batsman in an IPL 

sql=""" select Player_Name,Country_Name,Batting_hand,sum(Runs_Scored) as Runs
        from Batsman_Scored a
        join Ball_by_Ball b
        on a.Match_Id=b.Match_Id 
        and a.Innings_No=b.Innings_No
        and a.Over_Id=b.Over_Id 
        and a.Ball_Id=b.Ball_Id
        join (select Player_Id,Player_Name,b.Country_Name, c.Batting_hand
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Batting_Style c
              on a.Batting_hand=c.Batting_Id) c
        on b.Striker=c.Player_Id
        group by c.Player_Id
        order by Runs desc; """

runs=pd.read_sql(sql, conn)
runs.head().style.background_gradient(subset=["Runs"],low=0.55)
# Out:
# <style type="text/css">
# #T_e0a3a_row0_col3, #T_e0a3a_row1_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e0a3a_row2_col3 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_e0a3a_row3_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_e0a3a_row4_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# </style>
# <table id="T_e0a3a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Batting_hand</th>
#       <th class="col_heading level0 col3" >Runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0a3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0a3a_row0_col0" class="data row0 col0" >SK Raina</td>
#       <td id="T_e0a3a_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_e0a3a_row0_col2" class="data row0 col2" >Left-hand bat</td>
#       <td id="T_e0a3a_row0_col3" class="data row0 col3" >4106</td>
#     </tr>
#     <tr>
#       <th id="T_e0a3a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0a3a_row1_col0" class="data row1 col0" >V Kohli</td>
#       <td id="T_e0a3a_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_e0a3a_row1_col2" class="data row1 col2" >Right-hand bat</td>
#       <td id="T_e0a3a_row1_col3" class="data row1 col3" >4105</td>
#     </tr>
#     <tr>
#       <th id="T_e0a3a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0a3a_row2_col0" class="data row2 col0" >RG Sharma</td>
#       <td id="T_e0a3a_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_e0a3a_row2_col2" class="data row2 col2" >Right-hand bat</td>
#       <td id="T_e0a3a_row2_col3" class="data row2 col3" >3874</td>
#     </tr>
#     <tr>
#       <th id="T_e0a3a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0a3a_row3_col0" class="data row3 col0" >G Gambhir</td>
#       <td id="T_e0a3a_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_e0a3a_row3_col2" class="data row3 col2" >Left-hand bat</td>
#       <td id="T_e0a3a_row3_col3" class="data row3 col3" >3634</td>
#     </tr>
#     <tr>
#       <th id="T_e0a3a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0a3a_row4_col0" class="data row4 col0" >CH Gayle</td>
#       <td id="T_e0a3a_row4_col1" class="data row4 col1" >West Indies</td>
#       <td id="T_e0a3a_row4_col2" class="data row4 col2" >Left-hand bat</td>
#       <td id="T_e0a3a_row4_col3" class="data row4 col3" >3447</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Player who got dismissed at duck(0 score) highest no of times

sql=""" select Player_Name,Country_Name,Batting_hand,count(runs) as ducks
        from(select Striker,sum(Runs_Scored) as runs
             from (select Match_Id,Innings_No,Over_Id,Ball_Id,Striker
                   from Ball_by_Ball 
                   where Striker in (select Player_Out
                                   from Wicket_Taken))a
            join Batsman_Scored b
            on a.Match_Id=b.Match_Id 
            and a.Innings_No=b.Innings_No
            and a.Over_Id=b.Over_Id 
            and a.Ball_Id=b.Ball_Id
            group by Striker,a.Match_Id
            having runs==0) a
        join (select Player_Id,Player_Name,b.Country_Name, c.Batting_hand
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Batting_Style c
              on a.Batting_hand=c.Batting_Id) b
        on a.Striker=b.Player_Id
        group by Player_Id
        order by ducks desc; """

ducks=pd.read_sql(sql, conn)
ducks.head().style.background_gradient(subset=["ducks"],low=0.55)
# Out:
# <style type="text/css">
# #T_f3ef3_row0_col3, #T_f3ef3_row1_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f3ef3_row2_col3, #T_f3ef3_row3_col3, #T_f3ef3_row4_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# </style>
# <table id="T_f3ef3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Batting_hand</th>
#       <th class="col_heading level0 col3" >ducks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3ef3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3ef3_row0_col0" class="data row0 col0" >Harbhajan Singh</td>
#       <td id="T_f3ef3_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_f3ef3_row0_col2" class="data row0 col2" >Right-hand bat</td>
#       <td id="T_f3ef3_row0_col3" class="data row0 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f3ef3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3ef3_row1_col0" class="data row1 col0" >G Gambhir</td>
#       <td id="T_f3ef3_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_f3ef3_row1_col2" class="data row1 col2" >Left-hand bat</td>
#       <td id="T_f3ef3_row1_col3" class="data row1 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f3ef3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3ef3_row2_col0" class="data row2 col0" >R Sharma</td>
#       <td id="T_f3ef3_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_f3ef3_row2_col2" class="data row2 col2" >Right-hand bat</td>
#       <td id="T_f3ef3_row2_col3" class="data row2 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f3ef3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3ef3_row3_col0" class="data row3 col0" >MK Pandey</td>
#       <td id="T_f3ef3_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_f3ef3_row3_col2" class="data row3 col2" >Right-hand bat</td>
#       <td id="T_f3ef3_row3_col3" class="data row3 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f3ef3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3ef3_row4_col0" class="data row4 col0" >PP Chawla</td>
#       <td id="T_f3ef3_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_f3ef3_row4_col2" class="data row4 col2" >Left-hand bat</td>
#       <td id="T_f3ef3_row4_col3" class="data row4 col3" >10</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highest run score by a batsman in an IPL match

sql=""" select Player_Name,Country_Name,runs as highest_score,balls,
        dots,fours,sixes
        from(select Striker,sum(Runs_Scored) as runs, count(Runs_Scored) as balls,
             sum(case when Runs_Scored==0 then 1 else 0 end) as dots,
             sum(case when Runs_Scored==4 then 1 else 0 end) as fours,
             sum(case when Runs_Scored==6 then 1 else 0 end) as sixes
             from Ball_by_Ball a
             join Batsman_Scored b
             on a.Match_Id=b.Match_Id 
             and a.Innings_No=b.Innings_No
             and a.Over_Id=b.Over_Id 
             and a.Ball_Id=b.Ball_Id
             group by Striker,a.Match_Id) a
        join (select Player_Id,Player_Name,b.Country_Name, c.Batting_hand
             from Player a
             join Country b
             on a.Country_Name=b.Country_Id
             join Batting_Style c
             on a.Batting_hand=c.Batting_Id) b
        on a.Striker=b.Player_Id
        order by highest_score desc; """

highest_score=pd.read_sql(sql, conn)
highest_score.head().style.background_gradient(subset=["highest_score"],low=0.55)
# Out:
# <style type="text/css">
# #T_11349_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_11349_row1_col2 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_11349_row2_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_11349_row3_col2 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_11349_row4_col2 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# </style>
# <table id="T_11349_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >highest_score</th>
#       <th class="col_heading level0 col3" >balls</th>
#       <th class="col_heading level0 col4" >dots</th>
#       <th class="col_heading level0 col5" >fours</th>
#       <th class="col_heading level0 col6" >sixes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11349_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11349_row0_col0" class="data row0 col0" >CH Gayle</td>
#       <td id="T_11349_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_11349_row0_col2" class="data row0 col2" >175</td>
#       <td id="T_11349_row0_col3" class="data row0 col3" >66</td>
#       <td id="T_11349_row0_col4" class="data row0 col4" >15</td>
#       <td id="T_11349_row0_col5" class="data row0 col5" >13</td>
#       <td id="T_11349_row0_col6" class="data row0 col6" >17</td>
#     </tr>
#     <tr>
#       <th id="T_11349_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11349_row1_col0" class="data row1 col0" >BB McCullum</td>
#       <td id="T_11349_row1_col1" class="data row1 col1" >New Zealand</td>
#       <td id="T_11349_row1_col2" class="data row1 col2" >158</td>
#       <td id="T_11349_row1_col3" class="data row1 col3" >73</td>
#       <td id="T_11349_row1_col4" class="data row1 col4" >19</td>
#       <td id="T_11349_row1_col5" class="data row1 col5" >10</td>
#       <td id="T_11349_row1_col6" class="data row1 col6" >13</td>
#     </tr>
#     <tr>
#       <th id="T_11349_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11349_row2_col0" class="data row2 col0" >AB de Villiers</td>
#       <td id="T_11349_row2_col1" class="data row2 col1" >South Africa</td>
#       <td id="T_11349_row2_col2" class="data row2 col2" >133</td>
#       <td id="T_11349_row2_col3" class="data row2 col3" >59</td>
#       <td id="T_11349_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_11349_row2_col5" class="data row2 col5" >19</td>
#       <td id="T_11349_row2_col6" class="data row2 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_11349_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11349_row3_col0" class="data row3 col0" >AB de Villiers</td>
#       <td id="T_11349_row3_col1" class="data row3 col1" >South Africa</td>
#       <td id="T_11349_row3_col2" class="data row3 col2" >129</td>
#       <td id="T_11349_row3_col3" class="data row3 col3" >52</td>
#       <td id="T_11349_row3_col4" class="data row3 col4" >14</td>
#       <td id="T_11349_row3_col5" class="data row3 col5" >10</td>
#       <td id="T_11349_row3_col6" class="data row3 col6" >12</td>
#     </tr>
#     <tr>
#       <th id="T_11349_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11349_row4_col0" class="data row4 col0" >CH Gayle</td>
#       <td id="T_11349_row4_col1" class="data row4 col1" >West Indies</td>
#       <td id="T_11349_row4_col2" class="data row4 col2" >128</td>
#       <td id="T_11349_row4_col3" class="data row4 col3" >62</td>
#       <td id="T_11349_row4_col4" class="data row4 col4" >21</td>
#       <td id="T_11349_row4_col5" class="data row4 col5" >7</td>
#       <td id="T_11349_row4_col6" class="data row4 col6" >13</td>
#     </tr>
#   </tbody>
# </table>

# %%
# No of fifties and centruies by a batsman in an IPL

sql=""" select Player_Name,Country_Name,
        sum(case when runs>=50 and runs<100 then 1 else 0 end) as fifties,
        sum(case when runs>=100 then 1 else 0 end) as centuries,
        max(runs) as highest_score
        from(select Striker,sum(Runs_Scored) as runs
             from Ball_by_Ball a
             join Batsman_Scored b
             on a.Match_Id=b.Match_Id 
             and a.Innings_No=b.Innings_No
             and a.Over_Id=b.Over_Id 
             and a.Ball_Id=b.Ball_Id
             group by Striker,a.Match_Id
             having runs>=50) a
        join (select Player_Id,Player_Name,b.Country_Name, c.Batting_hand
             from Player a
             join Country b
             on a.Country_Name=b.Country_Id
             join Batting_Style c
             on a.Batting_hand=c.Batting_Id) b
        on a.Striker=b.Player_Id
        group by Player_Id
        order by fifties+centuries desc; """

best_player=pd.read_sql(sql, conn)
best_player.head(10).style.background_gradient(subset=["fifties","centuries","highest_score"],low=0.55,axis=0)
# Out:
# <style type="text/css">
# #T_b62e0_row0_col2, #T_b62e0_row5_col3, #T_b62e0_row5_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b62e0_row0_col3 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_b62e0_row0_col4, #T_b62e0_row3_col3, #T_b62e0_row3_col4, #T_b62e0_row4_col3, #T_b62e0_row8_col3, #T_b62e0_row9_col3 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_b62e0_row1_col2 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_b62e0_row1_col3, #T_b62e0_row1_col4, #T_b62e0_row7_col3, #T_b62e0_row9_col2 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_b62e0_row2_col2 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_b62e0_row2_col3 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_b62e0_row2_col4 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_b62e0_row3_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_b62e0_row4_col2 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_b62e0_row4_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_b62e0_row5_col2 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_b62e0_row6_col2 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_b62e0_row6_col3 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_b62e0_row6_col4 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_b62e0_row7_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_b62e0_row7_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_b62e0_row8_col2 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_b62e0_row8_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_b62e0_row9_col4 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b62e0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >fifties</th>
#       <th class="col_heading level0 col3" >centuries</th>
#       <th class="col_heading level0 col4" >highest_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b62e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b62e0_row0_col0" class="data row0 col0" >DA Warner</td>
#       <td id="T_b62e0_row0_col1" class="data row0 col1" >Australia</td>
#       <td id="T_b62e0_row0_col2" class="data row0 col2" >32</td>
#       <td id="T_b62e0_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_b62e0_row0_col4" class="data row0 col4" >109</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b62e0_row1_col0" class="data row1 col0" >G Gambhir</td>
#       <td id="T_b62e0_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_b62e0_row1_col2" class="data row1 col2" >31</td>
#       <td id="T_b62e0_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_b62e0_row1_col4" class="data row1 col4" >93</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b62e0_row2_col0" class="data row2 col0" >V Kohli</td>
#       <td id="T_b62e0_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_b62e0_row2_col2" class="data row2 col2" >27</td>
#       <td id="T_b62e0_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_b62e0_row2_col4" class="data row2 col4" >113</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b62e0_row3_col0" class="data row3 col0" >RG Sharma</td>
#       <td id="T_b62e0_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_b62e0_row3_col2" class="data row3 col2" >29</td>
#       <td id="T_b62e0_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_b62e0_row3_col4" class="data row3 col4" >109</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b62e0_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_b62e0_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_b62e0_row4_col2" class="data row4 col2" >28</td>
#       <td id="T_b62e0_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_b62e0_row4_col4" class="data row4 col4" >100</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b62e0_row5_col0" class="data row5 col0" >CH Gayle</td>
#       <td id="T_b62e0_row5_col1" class="data row5 col1" >West Indies</td>
#       <td id="T_b62e0_row5_col2" class="data row5 col2" >21</td>
#       <td id="T_b62e0_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_b62e0_row5_col4" class="data row5 col4" >175</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b62e0_row6_col0" class="data row6 col0" >AB de Villiers</td>
#       <td id="T_b62e0_row6_col1" class="data row6 col1" >South Africa</td>
#       <td id="T_b62e0_row6_col2" class="data row6 col2" >22</td>
#       <td id="T_b62e0_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_b62e0_row6_col4" class="data row6 col4" >133</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b62e0_row7_col0" class="data row7 col0" >S Dhawan</td>
#       <td id="T_b62e0_row7_col1" class="data row7 col1" >India</td>
#       <td id="T_b62e0_row7_col2" class="data row7 col2" >25</td>
#       <td id="T_b62e0_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_b62e0_row7_col4" class="data row7 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b62e0_row8_col0" class="data row8 col0" >AM Rahane</td>
#       <td id="T_b62e0_row8_col1" class="data row8 col1" >India</td>
#       <td id="T_b62e0_row8_col2" class="data row8 col2" >23</td>
#       <td id="T_b62e0_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_b62e0_row8_col4" class="data row8 col4" >103</td>
#     </tr>
#     <tr>
#       <th id="T_b62e0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b62e0_row9_col0" class="data row9 col0" >SE Marsh</td>
#       <td id="T_b62e0_row9_col1" class="data row9 col1" >Australia</td>
#       <td id="T_b62e0_row9_col2" class="data row9 col2" >18</td>
#       <td id="T_b62e0_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_b62e0_row9_col4" class="data row9 col4" >115</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Power Hitters of IPL

sql=""" select Player_Name,Country_Name,boundaries,fours,sixes
        from(select Striker,
             sum(case when Runs_Scored==4 or Runs_Scored==6 then 1 else 0 end) as boundaries,
             sum(case when Runs_Scored==4 then 1 else 0 end) as fours,
             sum(case when Runs_Scored==6 then 1 else 0 end) as sixes
             from Ball_by_Ball a
            join Batsman_Scored b
            on a.Match_Id=b.Match_Id 
            and a.Innings_No=b.Innings_No
            and a.Over_Id=b.Over_Id 
            and a.Ball_Id=b.Ball_Id
            group by Striker) a
        join (select Player_Id,Player_Name,b.Country_Name, c.Batting_hand
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Batting_Style c
              on a.Batting_hand=c.Batting_Id) b
        on a.Striker=b.Player_Id
        order by sixes desc; """

power_hitters=pd.read_sql(sql, conn)
power_hitters.head().style.background_gradient(subset=["boundaries","sixes","fours"],low=0.55,axis=0)
# Out:
# <style type="text/css">
# #T_3b730_row0_col2, #T_3b730_row0_col4, #T_3b730_row2_col3, #T_3b730_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3b730_row0_col3 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_3b730_row1_col2, #T_3b730_row1_col3 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_3b730_row1_col4 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_3b730_row2_col2 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_3b730_row2_col4 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_3b730_row3_col2 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_3b730_row3_col4 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_3b730_row4_col2, #T_3b730_row4_col3, #T_3b730_row4_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# </style>
# <table id="T_3b730_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >boundaries</th>
#       <th class="col_heading level0 col3" >fours</th>
#       <th class="col_heading level0 col4" >sixes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b730_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b730_row0_col0" class="data row0 col0" >CH Gayle</td>
#       <td id="T_3b730_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_3b730_row0_col2" class="data row0 col2" >533</td>
#       <td id="T_3b730_row0_col3" class="data row0 col3" >281</td>
#       <td id="T_3b730_row0_col4" class="data row0 col4" >252</td>
#     </tr>
#     <tr>
#       <th id="T_3b730_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b730_row1_col0" class="data row1 col0" >RG Sharma</td>
#       <td id="T_3b730_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_3b730_row1_col2" class="data row1 col2" >487</td>
#       <td id="T_3b730_row1_col3" class="data row1 col3" >323</td>
#       <td id="T_3b730_row1_col4" class="data row1 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_3b730_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3b730_row2_col0" class="data row2 col0" >SK Raina</td>
#       <td id="T_3b730_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_3b730_row2_col2" class="data row2 col2" >521</td>
#       <td id="T_3b730_row2_col3" class="data row2 col3" >360</td>
#       <td id="T_3b730_row2_col4" class="data row2 col4" >161</td>
#     </tr>
#     <tr>
#       <th id="T_3b730_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3b730_row3_col0" class="data row3 col0" >V Kohli</td>
#       <td id="T_3b730_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_3b730_row3_col2" class="data row3 col2" >508</td>
#       <td id="T_3b730_row3_col3" class="data row3 col3" >360</td>
#       <td id="T_3b730_row3_col4" class="data row3 col4" >148</td>
#     </tr>
#     <tr>
#       <th id="T_3b730_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3b730_row4_col0" class="data row4 col0" >YK Pathan</td>
#       <td id="T_3b730_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_3b730_row4_col2" class="data row4 col2" >374</td>
#       <td id="T_3b730_row4_col3" class="data row4 col3" >231</td>
#       <td id="T_3b730_row4_col4" class="data row4 col4" >143</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Batsman's with Highest strike rate and batting_average in IPL

sql="""select Player_Name as Player,Country_Name
       Matches,Runs,
       round(round(Runs,2)/round(dismissals,2),2) as Batting_Avg,Strike_Rate
       from(select Striker,sum(coalesce(Runs_Scored,0)) as Runs,
             100*round(round(sum(coalesce(Runs_Scored,0)),2)/round(count(*),2),4) as Strike_Rate
             from Ball_by_Ball a
             left join Batsman_Scored b
             on a.Match_Id=b.Match_Id 
             and a.Innings_No=b.Innings_No
             and a.Over_Id=b.Over_Id 
             and a.Ball_Id=b.Ball_Id
             left join Extra_Runs c
             on a.Match_Id=c.Match_Id 
             and a.Innings_No=c.Innings_No
             and a.Over_Id=c.Over_Id 
             and a.Ball_Id=c.Ball_Id
             where Extra_Type_Id !=2 or Extra_Type_Id is null
             group by Striker) a
        join(select Player_Out,count(*) as dismissals
             from Wicket_Taken
             group by Player_Out) b
        on a.Striker=b.Player_Out
        join( select Striker,count (distinct Match_Id)as Matches
              from Ball_by_Ball
              group by Striker) c
        on a.Striker=c.Striker
        join (select Player_Id,Player_Name,b.Country_Name, c.Batting_hand
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Batting_Style c
              on a.Batting_hand=c.Batting_Id) d
        on a.Striker=d.Player_Id
        where Matches>=50
        order by Batting_Avg desc,Strike_Rate desc ; """

highest_avg=pd.read_sql(sql, conn)
subset=["Runs","Batting_Avg","Strike_Rate"]
highest_avg.head(5).style.background_gradient(subset=subset,low=0.55)
# Out:
# <style type="text/css">
# #T_36b38_row0_col2, #T_36b38_row0_col3, #T_36b38_row0_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_36b38_row1_col2 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_36b38_row1_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_36b38_row1_col4 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_36b38_row2_col2, #T_36b38_row2_col4, #T_36b38_row3_col3, #T_36b38_row4_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_36b38_row2_col3 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_36b38_row3_col2, #T_36b38_row4_col2 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_36b38_row3_col4 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_36b38_row4_col4 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36b38_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player</th>
#       <th class="col_heading level0 col1" >Matches</th>
#       <th class="col_heading level0 col2" >Runs</th>
#       <th class="col_heading level0 col3" >Batting_Avg</th>
#       <th class="col_heading level0 col4" >Strike_Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36b38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36b38_row0_col0" class="data row0 col0" >CH Gayle</td>
#       <td id="T_36b38_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_36b38_row0_col2" class="data row0 col2" >3447</td>
#       <td id="T_36b38_row0_col3" class="data row0 col3" >43.090000</td>
#       <td id="T_36b38_row0_col4" class="data row0 col4" >153.470000</td>
#     </tr>
#     <tr>
#       <th id="T_36b38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36b38_row1_col0" class="data row1 col0" >SE Marsh</td>
#       <td id="T_36b38_row1_col1" class="data row1 col1" >Australia</td>
#       <td id="T_36b38_row1_col2" class="data row1 col2" >2225</td>
#       <td id="T_36b38_row1_col3" class="data row1 col3" >40.450000</td>
#       <td id="T_36b38_row1_col4" class="data row1 col4" >132.680000</td>
#     </tr>
#     <tr>
#       <th id="T_36b38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36b38_row2_col0" class="data row2 col0" >JP Duminy</td>
#       <td id="T_36b38_row2_col1" class="data row2 col1" >South Africa</td>
#       <td id="T_36b38_row2_col2" class="data row2 col2" >1993</td>
#       <td id="T_36b38_row2_col3" class="data row2 col3" >39.860000</td>
#       <td id="T_36b38_row2_col4" class="data row2 col4" >124.870000</td>
#     </tr>
#     <tr>
#       <th id="T_36b38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_36b38_row3_col0" class="data row3 col0" >AB de Villiers</td>
#       <td id="T_36b38_row3_col1" class="data row3 col1" >South Africa</td>
#       <td id="T_36b38_row3_col2" class="data row3 col2" >3270</td>
#       <td id="T_36b38_row3_col3" class="data row3 col3" >39.400000</td>
#       <td id="T_36b38_row3_col4" class="data row3 col4" >149.660000</td>
#     </tr>
#     <tr>
#       <th id="T_36b38_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_36b38_row4_col0" class="data row4 col0" >MS Dhoni</td>
#       <td id="T_36b38_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_36b38_row4_col2" class="data row4 col2" >3270</td>
#       <td id="T_36b38_row4_col3" class="data row4 col3" >39.400000</td>
#       <td id="T_36b38_row4_col4" class="data row4 col4" >138.910000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Batsman's with lowest strike rate and batting_average in IPL

subset=["Runs","Batting_Avg","Strike_Rate"]
lowest_avg=highest_avg.tail().iloc[::-1,:].reset_index(drop=True)
lowest_avg.style.background_gradient(subset=subset,low=0.55)
# Out:
# <style type="text/css">
# #T_eaf76_row0_col2, #T_eaf76_row0_col3, #T_eaf76_row0_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_eaf76_row1_col2 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_eaf76_row1_col3 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_eaf76_row1_col4 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_eaf76_row2_col2 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_eaf76_row2_col3 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_eaf76_row2_col4, #T_eaf76_row4_col2, #T_eaf76_row4_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_eaf76_row3_col2 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_eaf76_row3_col3 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_eaf76_row3_col4 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_eaf76_row4_col4 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eaf76_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player</th>
#       <th class="col_heading level0 col1" >Matches</th>
#       <th class="col_heading level0 col2" >Runs</th>
#       <th class="col_heading level0 col3" >Batting_Avg</th>
#       <th class="col_heading level0 col4" >Strike_Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaf76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaf76_row0_col0" class="data row0 col0" >P Kumar</td>
#       <td id="T_eaf76_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_eaf76_row0_col2" class="data row0 col2" >332</td>
#       <td id="T_eaf76_row0_col3" class="data row0 col3" >8.970000</td>
#       <td id="T_eaf76_row0_col4" class="data row0 col4" >108.850000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eaf76_row1_col0" class="data row1 col0" >PP Chawla</td>
#       <td id="T_eaf76_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_eaf76_row1_col2" class="data row1 col2" >513</td>
#       <td id="T_eaf76_row1_col3" class="data row1 col3" >12.510000</td>
#       <td id="T_eaf76_row1_col4" class="data row1 col4" >114.770000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf76_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eaf76_row2_col0" class="data row2 col0" >Harbhajan Singh</td>
#       <td id="T_eaf76_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_eaf76_row2_col2" class="data row2 col2" >783</td>
#       <td id="T_eaf76_row2_col3" class="data row2 col3" >15.980000</td>
#       <td id="T_eaf76_row2_col4" class="data row2 col4" >143.670000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf76_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eaf76_row3_col0" class="data row3 col0" >AM Nayar</td>
#       <td id="T_eaf76_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_eaf76_row3_col2" class="data row3 col2" >672</td>
#       <td id="T_eaf76_row3_col3" class="data row3 col3" >17.680000</td>
#       <td id="T_eaf76_row3_col4" class="data row3 col4" >116.460000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf76_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eaf76_row4_col0" class="data row4 col0" >NV Ojha</td>
#       <td id="T_eaf76_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_eaf76_row4_col2" class="data row4 col2" >1474</td>
#       <td id="T_eaf76_row4_col3" class="data row4 col3" >21.060000</td>
#       <td id="T_eaf76_row4_col4" class="data row4 col4" >118.490000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Best Batsman's in IPL

sql=""" select Player_Name as Player,
        Matches,Runs,Strike_Rate,
        round(round(Runs,2)/round(dismissals,2),2) as Batting_Avg,
        fifties,centuries,Best_Score
        from(select Striker,sum(coalesce(Runs_Scored,0)) as Runs,
             100*round(round(sum(coalesce(Runs_Scored,0)),2)/round(count(*),2),4) as Strike_Rate
             from Ball_by_Ball a
             left join Batsman_Scored b
             on a.Match_Id=b.Match_Id 
             and a.Innings_No=b.Innings_No
             and a.Over_Id=b.Over_Id 
             and a.Ball_Id=b.Ball_Id
             left join Extra_Runs c
             on a.Match_Id=c.Match_Id 
             and a.Innings_No=c.Innings_No
             and a.Over_Id=c.Over_Id 
             and a.Ball_Id=c.Ball_Id
             where Extra_Type_Id !=2 or Extra_Type_Id is null
             group by Striker) a
        join(select Player_Out,count(*) as dismissals
             from Wicket_Taken
             group by Player_Out) b
        on a.Striker=b.Player_Out
        join( select Striker,sum(case when runs==0 then 1 else 0 end) as Ducks,
              sum(case when runs>=50 and runs<100 then 1 else 0 end) as fifties,
              sum(case when runs>=100 then 1 else 0 end) as centuries,
              max(runs) as Best_Score
              from(select Striker,sum(Runs_Scored) as runs
                   from Ball_by_Ball a
                   join Batsman_Scored b
                   on a.Match_Id=b.Match_Id 
                   and a.Innings_No=b.Innings_No
                   and a.Over_Id=b.Over_Id 
                   and a.Ball_Id=b.Ball_Id
                   group by Striker,a.Match_Id)
               group by Striker) c
        on a.Striker=c.Striker
        join(select Striker,
             sum(case when Runs_Scored==4 then 1 else 0 end) as Fours,
             sum(case when Runs_Scored==6 then 1 else 0 end) as Sixes
             from Ball_by_Ball a
             join Batsman_Scored b
             on a.Match_Id=b.Match_Id 
             and a.Innings_No=b.Innings_No
             and a.Over_Id=b.Over_Id 
             and a.Ball_Id=b.Ball_Id
             group by Striker) d
        on a.Striker=d.Striker
        join( select Striker,count (distinct Match_Id)as Matches
              from Ball_by_Ball
              group by Striker) e
        on a.Striker=e.Striker
        join (select Player_Id,Player_Name,b.Country_Name, c.Batting_hand
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Batting_Style c
              on a.Batting_hand=c.Batting_Id) f
        on a.Striker=f.Player_Id
        where Matches>=50
        order by Batting_Avg desc,Strike_Rate desc; """
            
best_batters=pd.read_sql(sql, conn)
subset=["Runs","Batting_Avg","Strike_Rate"]
best_batters.head().style.background_gradient(subset=subset,low=0.55)
# Out:
# <style type="text/css">
# #T_bc010_row0_col2, #T_bc010_row0_col3, #T_bc010_row0_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bc010_row1_col2 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_bc010_row1_col3 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_bc010_row1_col4 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_bc010_row2_col2, #T_bc010_row2_col3, #T_bc010_row3_col4, #T_bc010_row4_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_bc010_row2_col4 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_bc010_row3_col2, #T_bc010_row4_col2 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_bc010_row3_col3 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_bc010_row4_col3 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc010_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player</th>
#       <th class="col_heading level0 col1" >Matches</th>
#       <th class="col_heading level0 col2" >Runs</th>
#       <th class="col_heading level0 col3" >Strike_Rate</th>
#       <th class="col_heading level0 col4" >Batting_Avg</th>
#       <th class="col_heading level0 col5" >fifties</th>
#       <th class="col_heading level0 col6" >centuries</th>
#       <th class="col_heading level0 col7" >Best_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc010_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc010_row0_col0" class="data row0 col0" >CH Gayle</td>
#       <td id="T_bc010_row0_col1" class="data row0 col1" >91</td>
#       <td id="T_bc010_row0_col2" class="data row0 col2" >3447</td>
#       <td id="T_bc010_row0_col3" class="data row0 col3" >153.470000</td>
#       <td id="T_bc010_row0_col4" class="data row0 col4" >43.090000</td>
#       <td id="T_bc010_row0_col5" class="data row0 col5" >21</td>
#       <td id="T_bc010_row0_col6" class="data row0 col6" >5</td>
#       <td id="T_bc010_row0_col7" class="data row0 col7" >175</td>
#     </tr>
#     <tr>
#       <th id="T_bc010_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc010_row1_col0" class="data row1 col0" >SE Marsh</td>
#       <td id="T_bc010_row1_col1" class="data row1 col1" >61</td>
#       <td id="T_bc010_row1_col2" class="data row1 col2" >2225</td>
#       <td id="T_bc010_row1_col3" class="data row1 col3" >132.680000</td>
#       <td id="T_bc010_row1_col4" class="data row1 col4" >40.450000</td>
#       <td id="T_bc010_row1_col5" class="data row1 col5" >18</td>
#       <td id="T_bc010_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_bc010_row1_col7" class="data row1 col7" >115</td>
#     </tr>
#     <tr>
#       <th id="T_bc010_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc010_row2_col0" class="data row2 col0" >JP Duminy</td>
#       <td id="T_bc010_row2_col1" class="data row2 col1" >73</td>
#       <td id="T_bc010_row2_col2" class="data row2 col2" >1993</td>
#       <td id="T_bc010_row2_col3" class="data row2 col3" >124.870000</td>
#       <td id="T_bc010_row2_col4" class="data row2 col4" >39.860000</td>
#       <td id="T_bc010_row2_col5" class="data row2 col5" >14</td>
#       <td id="T_bc010_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_bc010_row2_col7" class="data row2 col7" >78</td>
#     </tr>
#     <tr>
#       <th id="T_bc010_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc010_row3_col0" class="data row3 col0" >AB de Villiers</td>
#       <td id="T_bc010_row3_col1" class="data row3 col1" >109</td>
#       <td id="T_bc010_row3_col2" class="data row3 col2" >3270</td>
#       <td id="T_bc010_row3_col3" class="data row3 col3" >149.660000</td>
#       <td id="T_bc010_row3_col4" class="data row3 col4" >39.400000</td>
#       <td id="T_bc010_row3_col5" class="data row3 col5" >22</td>
#       <td id="T_bc010_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_bc010_row3_col7" class="data row3 col7" >133</td>
#     </tr>
#     <tr>
#       <th id="T_bc010_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc010_row4_col0" class="data row4 col0" >MS Dhoni</td>
#       <td id="T_bc010_row4_col1" class="data row4 col1" >128</td>
#       <td id="T_bc010_row4_col2" class="data row4 col2" >3270</td>
#       <td id="T_bc010_row4_col3" class="data row4 col3" >138.910000</td>
#       <td id="T_bc010_row4_col4" class="data row4 col4" >39.400000</td>
#       <td id="T_bc010_row4_col5" class="data row4 col5" >16</td>
#       <td id="T_bc010_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_bc010_row4_col7" class="data row4 col7" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Fielding Statistics

# %%
#Best Fielders in IPL

sql=""" select Player_Name,Country_Name,dismissals,catch,run_out
        from(select Player_Name,Country_Name,count(Kind_Out) as dismissals,
             sum(case when Kind_Out==1 then 1 else 0 end) as catch,
             sum(case when Kind_Out==3 then 1 else 0 end) as run_out,
             sum(case when Kind_Out==6 then 1 else 0 end) as stumping
             from Wicket_Taken a
             join (select Player_Id,Player_Name,b.Country_Name
                   from Player a
                   join Country b
                   on a.Country_Name=b.Country_Id) b
             on a.Fielders=b.Player_Id
             where Kind_Out in (1,3,6)
             group by b.Player_Id
             having stumping=0
             order by dismissals desc) ; """

fielders=pd.read_sql(sql, conn)
fielders.head().style.background_gradient(subset=['dismissals',"catch","run_out"],cmap="Greens",low=0.35)
# Out:
# <style type="text/css">
# #T_5c48a_row0_col2, #T_5c48a_row0_col3, #T_5c48a_row2_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5c48a_row0_col4, #T_5c48a_row3_col4 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_5c48a_row1_col2 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_5c48a_row1_col3 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_5c48a_row1_col4, #T_5c48a_row2_col3 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_5c48a_row2_col2 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_5c48a_row3_col2 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_5c48a_row3_col3 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_5c48a_row4_col2, #T_5c48a_row4_col3, #T_5c48a_row4_col4 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# </style>
# <table id="T_5c48a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >dismissals</th>
#       <th class="col_heading level0 col3" >catch</th>
#       <th class="col_heading level0 col4" >run_out</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c48a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c48a_row0_col0" class="data row0 col0" >SK Raina</td>
#       <td id="T_5c48a_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_5c48a_row0_col2" class="data row0 col2" >91</td>
#       <td id="T_5c48a_row0_col3" class="data row0 col3" >79</td>
#       <td id="T_5c48a_row0_col4" class="data row0 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_5c48a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5c48a_row1_col0" class="data row1 col0" >RG Sharma</td>
#       <td id="T_5c48a_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_5c48a_row1_col2" class="data row1 col2" >69</td>
#       <td id="T_5c48a_row1_col3" class="data row1 col3" >60</td>
#       <td id="T_5c48a_row1_col4" class="data row1 col4" >9</td>
#     </tr>
#     <tr>
#       <th id="T_5c48a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5c48a_row2_col0" class="data row2 col0" >V Kohli</td>
#       <td id="T_5c48a_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_5c48a_row2_col2" class="data row2 col2" >68</td>
#       <td id="T_5c48a_row2_col3" class="data row2 col3" >55</td>
#       <td id="T_5c48a_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_5c48a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5c48a_row3_col0" class="data row3 col0" >DJ Bravo</td>
#       <td id="T_5c48a_row3_col1" class="data row3 col1" >West Indies</td>
#       <td id="T_5c48a_row3_col2" class="data row3 col2" >64</td>
#       <td id="T_5c48a_row3_col3" class="data row3 col3" >52</td>
#       <td id="T_5c48a_row3_col4" class="data row3 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_5c48a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5c48a_row4_col0" class="data row4 col0" >KA Pollard</td>
#       <td id="T_5c48a_row4_col1" class="data row4 col1" >West Indies</td>
#       <td id="T_5c48a_row4_col2" class="data row4 col2" >57</td>
#       <td id="T_5c48a_row4_col3" class="data row4 col3" >49</td>
#       <td id="T_5c48a_row4_col4" class="data row4 col4" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Best Wicket-Keepers in IPL

sql=""" select Player_Name,Country_Name,count(Kind_Out) as dismissals,
        sum(case when Kind_Out==1 then 1 else 0 end) as catch,
        sum(case when Kind_Out==3 then 1 else 0 end) as run_out,
        sum(case when Kind_Out==6 then 1 else 0 end) as stumping
        from Wicket_Taken a
        join (select Player_Id,Player_Name,b.Country_Name
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id) b
        on a.Fielders=b.Player_Id
        where Kind_Out in (1,3,6)
        group by b.Player_Id
        having stumping!=0
        order by dismissals desc; """

keepers=pd.read_sql(sql, conn)
keepers.head().style.background_gradient(subset=['dismissals',"catch","run_out","stumping"],cmap="Greens",low=0.35)
# Out:
# <style type="text/css">
# #T_df653_row0_col2, #T_df653_row0_col3, #T_df653_row1_col4, #T_df653_row1_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_df653_row0_col4, #T_df653_row3_col4 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_df653_row0_col5, #T_df653_row2_col5 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_df653_row1_col2 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_df653_row1_col3, #T_df653_row2_col3 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_df653_row2_col2 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_df653_row2_col4 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_df653_row3_col2 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_df653_row3_col3 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_df653_row3_col5, #T_df653_row4_col2, #T_df653_row4_col3, #T_df653_row4_col4 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_df653_row4_col5 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# </style>
# <table id="T_df653_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >dismissals</th>
#       <th class="col_heading level0 col3" >catch</th>
#       <th class="col_heading level0 col4" >run_out</th>
#       <th class="col_heading level0 col5" >stumping</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df653_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df653_row0_col0" class="data row0 col0" >KD Karthik</td>
#       <td id="T_df653_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_df653_row0_col2" class="data row0 col2" >119</td>
#       <td id="T_df653_row0_col3" class="data row0 col3" >80</td>
#       <td id="T_df653_row0_col4" class="data row0 col4" >13</td>
#       <td id="T_df653_row0_col5" class="data row0 col5" >26</td>
#     </tr>
#     <tr>
#       <th id="T_df653_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_df653_row1_col0" class="data row1 col0" >MS Dhoni</td>
#       <td id="T_df653_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_df653_row1_col2" class="data row1 col2" >111</td>
#       <td id="T_df653_row1_col3" class="data row1 col3" >66</td>
#       <td id="T_df653_row1_col4" class="data row1 col4" >18</td>
#       <td id="T_df653_row1_col5" class="data row1 col5" >27</td>
#     </tr>
#     <tr>
#       <th id="T_df653_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_df653_row2_col0" class="data row2 col0" >RV Uthappa</td>
#       <td id="T_df653_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_df653_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_df653_row2_col3" class="data row2 col3" >66</td>
#       <td id="T_df653_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_df653_row2_col5" class="data row2 col5" >26</td>
#     </tr>
#     <tr>
#       <th id="T_df653_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_df653_row3_col0" class="data row3 col0" >AB de Villiers</td>
#       <td id="T_df653_row3_col1" class="data row3 col1" >South Africa</td>
#       <td id="T_df653_row3_col2" class="data row3 col2" >97</td>
#       <td id="T_df653_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_df653_row3_col4" class="data row3 col4" >13</td>
#       <td id="T_df653_row3_col5" class="data row3 col5" >7</td>
#     </tr>
#     <tr>
#       <th id="T_df653_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_df653_row4_col0" class="data row4 col0" >NV Ojha</td>
#       <td id="T_df653_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_df653_row4_col2" class="data row4 col2" >76</td>
#       <td id="T_df653_row4_col3" class="data row4 col3" >59</td>
#       <td id="T_df653_row4_col4" class="data row4 col4" >7</td>
#       <td id="T_df653_row4_col5" class="data row4 col5" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Captain Statistics

# %%
# Most successful captains of IPL

sql="""select Player_Name as Captain,Country_Name,
       count(*) as Matches,
       sum(case when a.Team_Id=b.Winner then 1 else 0 end) as Wins,
       round(round(sum(case when a.Team_Id=b.Winner then 1 else 0 end),2)/round(count(*),2),2) as Win_perc,
       round(round(sum(case when a.Team_Id=b.Winner then chasing else 0 end),2)/round(sum(case when a.Team_Id!=b.Winner then defending else 0 end+case when a.Team_Id=b.Winner then chasing else 0 end),2),2) as Chasing_perc ,
       round(round(sum(case when a.Team_Id=b.Winner then defending else 0 end),2)/round(sum(case when a.Team_Id!=b.Winner then chasing else 0 end+case when a.Team_Id=b.Winner then defending else 0 end),2),2) as Defending_perc
       from (select Match_Id,Team_Id,Player_Id
             from Player_Match 
             where Role_Id in (1,4)
             group by Match_Id,Team_Id,Player_Id) a
       left join(select Match_Id, 
                 case when Win_Type==1 
                      then case when Toss_Winner=Team_1 and Toss_Decide=2 then Team_1
                                when Toss_Winner=Team_1 and Toss_Decide=1 then Team_2
                                when Toss_Winner=Team_2 and Toss_Decide=2 then Team_2
                                else Team_1 end
                      else case when Toss_Winner=Team_1 and Toss_Decide=2 then Team_2
                                when Toss_Winner=Team_1 and Toss_Decide=1 then Team_1
                                when Toss_Winner=Team_2 and Toss_Decide=2 then Team_1
                                else Team_2 end 
                      end as Winner,
                case when Win_Type==1 then 1 else 0 end as defending,
                case when Win_Type==2 then 1 else 0 end as chasing
                from Match a
                where Win_Type in (1,2)) as b
        on a.Match_Id=b.Match_Id
        join( select Player_Id,Player_Name,b.Country_Name
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id) c
        on a.Player_Id=c.Player_Id
        group by a.Player_Id
        having Matches>=30
        order by Win_perc desc, Chasing_perc desc,Defending_perc desc; """

best_captain=pd.read_sql(sql, conn)
subset=["Win_perc","Defending_perc","Chasing_perc"]
best_captain.head(10).style.background_gradient(subset=subset,cmap="Purples",low=0.35)
# Out:
# <style type="text/css">
# #T_0c16e_row0_col4, #T_0c16e_row1_col4, #T_0c16e_row2_col6, #T_0c16e_row5_col5 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_0c16e_row0_col5 {
#   background-color: #4b1687;
#   color: #f1f1f1;
# }
# #T_0c16e_row0_col6, #T_0c16e_row3_col6 {
#   background-color: #7d77b7;
#   color: #f1f1f1;
# }
# #T_0c16e_row1_col5 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_0c16e_row1_col6 {
#   background-color: #582e92;
#   color: #f1f1f1;
# }
# #T_0c16e_row2_col4 {
#   background-color: #491285;
#   color: #f1f1f1;
# }
# #T_0c16e_row2_col5 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_0c16e_row3_col4 {
#   background-color: #53268f;
#   color: #f1f1f1;
# }
# #T_0c16e_row3_col5 {
#   background-color: #65479e;
#   color: #f1f1f1;
# }
# #T_0c16e_row4_col4, #T_0c16e_row7_col5 {
#   background-color: #5e3b98;
#   color: #f1f1f1;
# }
# #T_0c16e_row4_col5 {
#   background-color: #6c54a5;
#   color: #f1f1f1;
# }
# #T_0c16e_row4_col6 {
#   background-color: #908dc2;
#   color: #f1f1f1;
# }
# #T_0c16e_row5_col4, #T_0c16e_row6_col4 {
#   background-color: #6950a3;
#   color: #f1f1f1;
# }
# #T_0c16e_row5_col6, #T_0c16e_row6_col6 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_0c16e_row6_col5 {
#   background-color: #450b82;
#   color: #f1f1f1;
# }
# #T_0c16e_row7_col4 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_0c16e_row7_col6 {
#   background-color: #b4b4d7;
#   color: #000000;
# }
# #T_0c16e_row8_col4 {
#   background-color: #bbbbdb;
#   color: #000000;
# }
# #T_0c16e_row8_col5 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_0c16e_row8_col6, #T_0c16e_row9_col4, #T_0c16e_row9_col5 {
#   background-color: #d8d8ea;
#   color: #000000;
# }
# #T_0c16e_row9_col6 {
#   background-color: #a6a3cd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0c16e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Captain</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Matches</th>
#       <th class="col_heading level0 col3" >Wins</th>
#       <th class="col_heading level0 col4" >Win_perc</th>
#       <th class="col_heading level0 col5" >Chasing_perc</th>
#       <th class="col_heading level0 col6" >Defending_perc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c16e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c16e_row0_col0" class="data row0 col0" >RG Sharma</td>
#       <td id="T_0c16e_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_0c16e_row0_col2" class="data row0 col2" >58</td>
#       <td id="T_0c16e_row0_col3" class="data row0 col3" >34</td>
#       <td id="T_0c16e_row0_col4" class="data row0 col4" >0.590000</td>
#       <td id="T_0c16e_row0_col5" class="data row0 col5" >0.640000</td>
#       <td id="T_0c16e_row0_col6" class="data row0 col6" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c16e_row1_col0" class="data row1 col0" >SR Tendulkar</td>
#       <td id="T_0c16e_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_0c16e_row1_col2" class="data row1 col2" >51</td>
#       <td id="T_0c16e_row1_col3" class="data row1 col3" >30</td>
#       <td id="T_0c16e_row1_col4" class="data row1 col4" >0.590000</td>
#       <td id="T_0c16e_row1_col5" class="data row1 col5" >0.550000</td>
#       <td id="T_0c16e_row1_col6" class="data row1 col6" >0.620000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c16e_row2_col0" class="data row2 col0" >DA Warner</td>
#       <td id="T_0c16e_row2_col1" class="data row2 col1" >Australia</td>
#       <td id="T_0c16e_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_0c16e_row2_col3" class="data row2 col3" >19</td>
#       <td id="T_0c16e_row2_col4" class="data row2 col4" >0.580000</td>
#       <td id="T_0c16e_row2_col5" class="data row2 col5" >0.470000</td>
#       <td id="T_0c16e_row2_col6" class="data row2 col6" >0.670000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c16e_row3_col0" class="data row3 col0" >MS Dhoni</td>
#       <td id="T_0c16e_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_0c16e_row3_col2" class="data row3 col2" >142</td>
#       <td id="T_0c16e_row3_col3" class="data row3 col3" >81</td>
#       <td id="T_0c16e_row3_col4" class="data row3 col4" >0.570000</td>
#       <td id="T_0c16e_row3_col5" class="data row3 col5" >0.600000</td>
#       <td id="T_0c16e_row3_col6" class="data row3 col6" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c16e_row4_col0" class="data row4 col0" >G Gambhir</td>
#       <td id="T_0c16e_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_0c16e_row4_col2" class="data row4 col2" >107</td>
#       <td id="T_0c16e_row4_col3" class="data row4 col3" >60</td>
#       <td id="T_0c16e_row4_col4" class="data row4 col4" >0.560000</td>
#       <td id="T_0c16e_row4_col5" class="data row4 col5" >0.590000</td>
#       <td id="T_0c16e_row4_col6" class="data row4 col6" >0.520000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c16e_row5_col0" class="data row5 col0" >V Sehwag</td>
#       <td id="T_0c16e_row5_col1" class="data row5 col1" >India</td>
#       <td id="T_0c16e_row5_col2" class="data row5 col2" >53</td>
#       <td id="T_0c16e_row5_col3" class="data row5 col3" >29</td>
#       <td id="T_0c16e_row5_col4" class="data row5 col4" >0.550000</td>
#       <td id="T_0c16e_row5_col5" class="data row5 col5" >0.660000</td>
#       <td id="T_0c16e_row5_col6" class="data row5 col6" >0.430000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c16e_row6_col0" class="data row6 col0" >SK Warne</td>
#       <td id="T_0c16e_row6_col1" class="data row6 col1" >Australia</td>
#       <td id="T_0c16e_row6_col2" class="data row6 col2" >55</td>
#       <td id="T_0c16e_row6_col3" class="data row6 col3" >30</td>
#       <td id="T_0c16e_row6_col4" class="data row6 col4" >0.550000</td>
#       <td id="T_0c16e_row6_col5" class="data row6 col5" >0.650000</td>
#       <td id="T_0c16e_row6_col6" class="data row6 col6" >0.430000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c16e_row7_col0" class="data row7 col0" >V Kohli</td>
#       <td id="T_0c16e_row7_col1" class="data row7 col1" >India</td>
#       <td id="T_0c16e_row7_col2" class="data row7 col2" >71</td>
#       <td id="T_0c16e_row7_col3" class="data row7 col3" >36</td>
#       <td id="T_0c16e_row7_col4" class="data row7 col4" >0.510000</td>
#       <td id="T_0c16e_row7_col5" class="data row7 col5" >0.610000</td>
#       <td id="T_0c16e_row7_col6" class="data row7 col6" >0.470000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c16e_row8_col0" class="data row8 col0" >Yuvraj Singh</td>
#       <td id="T_0c16e_row8_col1" class="data row8 col1" >India</td>
#       <td id="T_0c16e_row8_col2" class="data row8 col2" >43</td>
#       <td id="T_0c16e_row8_col3" class="data row8 col3" >21</td>
#       <td id="T_0c16e_row8_col4" class="data row8 col4" >0.490000</td>
#       <td id="T_0c16e_row8_col5" class="data row8 col5" >0.570000</td>
#       <td id="T_0c16e_row8_col6" class="data row8 col6" >0.420000</td>
#     </tr>
#     <tr>
#       <th id="T_0c16e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c16e_row9_col0" class="data row9 col0" >AC Gilchrist</td>
#       <td id="T_0c16e_row9_col1" class="data row9 col1" >Australia</td>
#       <td id="T_0c16e_row9_col2" class="data row9 col2" >74</td>
#       <td id="T_0c16e_row9_col3" class="data row9 col3" >35</td>
#       <td id="T_0c16e_row9_col4" class="data row9 col4" >0.470000</td>
#       <td id="T_0c16e_row9_col5" class="data row9 col5" >0.460000</td>
#       <td id="T_0c16e_row9_col6" class="data row9 col6" >0.490000</td>
#     </tr>
#   </tb

# %% [markdown]
# ### Team Statistics

# %%
# Best Teams in IPL

sql=""" select Team_Name as franchise,
        a.matches+b.matches as Matches,c.Wins,
        round(round(Wins,2)/round(a.matches+b.matches,2),2) as Win_perc
        from( select Season_Id,Team_1,
              count(*) as matches
              from Match
              group by Team_1) a
        join( select Season_Id,Team_2,
              count(*) as matches
              from Match
              group by Team_2) b
        on a.Team_1=b.Team_2
        join (select Match_Winner,
              count(*) as Wins
              from Match
              where Match_Winner is not null
              group by Match_Winner) c
        on a.Team_1=c.Match_Winner
        join Team d
        on a.Team_1=d.Team_Id
        order by Win_perc desc; """

best_teams=pd.read_sql(sql, conn).set_index("franchise")
best_teams.style.background_gradient(subset=["Wins","Win_perc"],cmap="Oranges",high=0.5)
# Out:
# <style type="text/css">
# #T_9c6f0_row0_col1 {
#   background-color: #eb600e;
#   color: #f1f1f1;
# }
# #T_9c6f0_row0_col2, #T_9c6f0_row1_col1 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_9c6f0_row1_col2 {
#   background-color: #f36e19;
#   color: #f1f1f1;
# }
# #T_9c6f0_row2_col1 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_9c6f0_row2_col2 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_9c6f0_row3_col1, #T_9c6f0_row10_col2 {
#   background-color: #fdcfa0;
#   color: #000000;
# }
# #T_9c6f0_row3_col2 {
#   background-color: #f67925;
#   color: #f1f1f1;
# }
# #T_9c6f0_row4_col1, #T_9c6f0_row7_col1 {
#   background-color: #fc8937;
#   color: #f1f1f1;
# }
# #T_9c6f0_row4_col2 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_9c6f0_row5_col1 {
#   background-color: #f77b28;
#   color: #f1f1f1;
# }
# #T_9c6f0_row5_col2 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_9c6f0_row6_col1 {
#   background-color: #f67723;
#   color: #f1f1f1;
# }
# #T_9c6f0_row6_col2 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_9c6f0_row7_col2 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_9c6f0_row8_col1 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_9c6f0_row8_col2 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_9c6f0_row9_col1 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_9c6f0_row9_col2 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_9c6f0_row10_col1 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# #T_9c6f0_row11_col1, #T_9c6f0_row12_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_9c6f0_row11_col2 {
#   background-color: #fdd9b5;
#   color: #000000;
# }
# #T_9c6f0_row12_col1 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# </style>
# <table id="T_9c6f0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Matches</th>
#       <th class="col_heading level0 col1" >Wins</th>
#       <th class="col_heading level0 col2" >Win_perc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >franchise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c6f0_level0_row0" class="row_heading level0 row0" >Chennai Super Kings</th>
#       <td id="T_9c6f0_row0_col0" class="data row0 col0" >131</td>
#       <td id="T_9c6f0_row0_col1" class="data row0 col1" >79</td>
#       <td id="T_9c6f0_row0_col2" class="data row0 col2" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row1" class="row_heading level0 row1" >Mumbai Indians</th>
#       <td id="T_9c6f0_row1_col0" class="data row1 col0" >140</td>
#       <td id="T_9c6f0_row1_col1" class="data row1 col1" >80</td>
#       <td id="T_9c6f0_row1_col2" class="data row1 col2" >0.570000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row2" class="row_heading level0 row2" >Gujarat Lions</th>
#       <td id="T_9c6f0_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_9c6f0_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_9c6f0_row2_col2" class="data row2 col2" >0.560000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row3" class="row_heading level0 row3" >Sunrisers Hyderabad</th>
#       <td id="T_9c6f0_row3_col0" class="data row3 col0" >62</td>
#       <td id="T_9c6f0_row3_col1" class="data row3 col1" >34</td>
#       <td id="T_9c6f0_row3_col2" class="data row3 col2" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row4" class="row_heading level0 row4" >Rajasthan Royals</th>
#       <td id="T_9c6f0_row4_col0" class="data row4 col0" >118</td>
#       <td id="T_9c6f0_row4_col1" class="data row4 col1" >63</td>
#       <td id="T_9c6f0_row4_col2" class="data row4 col2" >0.530000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row5" class="row_heading level0 row5" >Kolkata Knight Riders</th>
#       <td id="T_9c6f0_row5_col0" class="data row5 col0" >132</td>
#       <td id="T_9c6f0_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_9c6f0_row5_col2" class="data row5 col2" >0.520000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row6" class="row_heading level0 row6" >Royal Challengers Bangalore</th>
#       <td id="T_9c6f0_row6_col0" class="data row6 col0" >139</td>
#       <td id="T_9c6f0_row6_col1" class="data row6 col1" >70</td>
#       <td id="T_9c6f0_row6_col2" class="data row6 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row7" class="row_heading level0 row7" >Kings XI Punjab</th>
#       <td id="T_9c6f0_row7_col0" class="data row7 col0" >134</td>
#       <td id="T_9c6f0_row7_col1" class="data row7 col1" >63</td>
#       <td id="T_9c6f0_row7_col2" class="data row7 col2" >0.470000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row8" class="row_heading level0 row8" >Kochi Tuskers Kerala</th>
#       <td id="T_9c6f0_row8_col0" class="data row8 col0" >14</td>
#       <td id="T_9c6f0_row8_col1" class="data row8 col1" >6</td>
#       <td id="T_9c6f0_row8_col2" class="data row8 col2" >0.430000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row9" class="row_heading level0 row9" >Delhi Daredevils</th>
#       <td id="T_9c6f0_row9_col0" class="data row9 col0" >133</td>
#       <td id="T_9c6f0_row9_col1" class="data row9 col1" >56</td>
#       <td id="T_9c6f0_row9_col2" class="data row9 col2" >0.420000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row10" class="row_heading level0 row10" >Deccan Chargers</th>
#       <td id="T_9c6f0_row10_col0" class="data row10 col0" >75</td>
#       <td id="T_9c6f0_row10_col1" class="data row10 col1" >29</td>
#       <td id="T_9c6f0_row10_col2" class="data row10 col2" >0.390000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row11" class="row_heading level0 row11" >Rising Pune Supergiants</th>
#       <td id="T_9c6f0_row11_col0" class="data row11 col0" >14</td>
#       <td id="T_9c6f0_row11_col1" class="data row11 col1" >5</td>
#       <td id="T_9c6f0_row11_col2" class="data row11 col2" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_9c6f0_level0_row12" class="row_heading level0 row12" >Pune Warriors</th>
#       <td id="T_9c6f0_row12_col0" class="data row12 col0" >46</td>
#       <td id="T_9c6f0_row12_col1" class="data row12 col1" >12</td>
#       <td id="T_9c6f0_row12_col2" class="data row12 col2" >0.260000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# best team in defending the score

sql=""" select 
        case when Toss_Winner=Team_1 and Toss_Decide=2 then b.Team_Name
             when Toss_Winner=Team_1 and Toss_Decide=1 then c.Team_Name
             when Toss_Winner=Team_2 and Toss_Decide=2 then c.Team_Name
             else b.Team_Name end as franchise,
        count(Match_Id) as matches,sum(case when Win_Type==1 then 1 else 0 end)as wins,
        round(round(sum(case when Win_Type==1 then 1 else 0 end),2)/round(count(Match_Id),2),2) as win_percentage
        from Match a
        join Team b
        on a.Team_1=b.Team_Id
        join Team c
        on a.Team_2=c.Team_Id
        group by franchise
        order by win_percentage desc; """

best_defenders=pd.read_sql(sql, conn).set_index("franchise")
best_defenders.style.background_gradient(subset=["win_percentage"],cmap="Oranges",high=0.5)
# Out:
# <style type="text/css">
# #T_862b5_row0_col2 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_862b5_row1_col2 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_862b5_row2_col2 {
#   background-color: #f67925;
#   color: #f1f1f1;
# }
# #T_862b5_row3_col2 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_862b5_row4_col2 {
#   background-color: #fd9040;
#   color: #000000;
# }
# #T_862b5_row5_col2 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_862b5_row6_col2 {
#   background-color: #fd9649;
#   color: #000000;
# }
# #T_862b5_row7_col2 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_862b5_row8_col2 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_862b5_row9_col2 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_862b5_row10_col2 {
#   background-color: #fdbd83;
#   color: #000000;
# }
# #T_862b5_row11_col2 {
#   background-color: #fddbb8;
#   color: #000000;
# }
# #T_862b5_row12_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_862b5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >matches</th>
#       <th class="col_heading level0 col1" >wins</th>
#       <th class="col_heading level0 col2" >win_percentage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >franchise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_862b5_level0_row0" class="row_heading level0 row0" >Chennai Super Kings</th>
#       <td id="T_862b5_row0_col0" class="data row0 col0" >77</td>
#       <td id="T_862b5_row0_col1" class="data row0 col1" >46</td>
#       <td id="T_862b5_row0_col2" class="data row0 col2" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row1" class="row_heading level0 row1" >Mumbai Indians</th>
#       <td id="T_862b5_row1_col0" class="data row1 col0" >76</td>
#       <td id="T_862b5_row1_col1" class="data row1 col1" >43</td>
#       <td id="T_862b5_row1_col2" class="data row1 col2" >0.570000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row2" class="row_heading level0 row2" >Sunrisers Hyderabad</th>
#       <td id="T_862b5_row2_col0" class="data row2 col0" >37</td>
#       <td id="T_862b5_row2_col1" class="data row2 col1" >19</td>
#       <td id="T_862b5_row2_col2" class="data row2 col2" >0.510000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row3" class="row_heading level0 row3" >Kolkata Knight Riders</th>
#       <td id="T_862b5_row3_col0" class="data row3 col0" >62</td>
#       <td id="T_862b5_row3_col1" class="data row3 col1" >28</td>
#       <td id="T_862b5_row3_col2" class="data row3 col2" >0.450000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row4" class="row_heading level0 row4" >Royal Challengers Bangalore</th>
#       <td id="T_862b5_row4_col0" class="data row4 col0" >62</td>
#       <td id="T_862b5_row4_col1" class="data row4 col1" >27</td>
#       <td id="T_862b5_row4_col2" class="data row4 col2" >0.440000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row5" class="row_heading level0 row5" >Rajasthan Royals</th>
#       <td id="T_862b5_row5_col0" class="data row5 col0" >54</td>
#       <td id="T_862b5_row5_col1" class="data row5 col1" >23</td>
#       <td id="T_862b5_row5_col2" class="data row5 col2" >0.430000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row6" class="row_heading level0 row6" >Deccan Chargers</th>
#       <td id="T_862b5_row6_col0" class="data row6 col0" >43</td>
#       <td id="T_862b5_row6_col1" class="data row6 col1" >18</td>
#       <td id="T_862b5_row6_col2" class="data row6 col2" >0.420000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row7" class="row_heading level0 row7" >Kings XI Punjab</th>
#       <td id="T_862b5_row7_col0" class="data row7 col0" >69</td>
#       <td id="T_862b5_row7_col1" class="data row7 col1" >28</td>
#       <td id="T_862b5_row7_col2" class="data row7 col2" >0.410000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row8" class="row_heading level0 row8" >Delhi Daredevils</th>
#       <td id="T_862b5_row8_col0" class="data row8 col0" >57</td>
#       <td id="T_862b5_row8_col1" class="data row8 col1" >20</td>
#       <td id="T_862b5_row8_col2" class="data row8 col2" >0.350000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row9" class="row_heading level0 row9" >Pune Warriors</th>
#       <td id="T_862b5_row9_col0" class="data row9 col0" >20</td>
#       <td id="T_862b5_row9_col1" class="data row9 col1" >6</td>
#       <td id="T_862b5_row9_col2" class="data row9 col2" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row10" class="row_heading level0 row10" >Kochi Tuskers Kerala</th>
#       <td id="T_862b5_row10_col0" class="data row10 col0" >7</td>
#       <td id="T_862b5_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_862b5_row10_col2" class="data row10 col2" >0.290000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row11" class="row_heading level0 row11" >Gujarat Lions</th>
#       <td id="T_862b5_row11_col0" class="data row11 col0" >6</td>
#       <td id="T_862b5_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_862b5_row11_col2" class="data row11 col2" >0.170000</td>
#     </tr>
#     <tr>
#       <th id="T_862b5_level0_row12" class="row_heading level0 row12" >Rising Pune Supergiants</th>
#       <td id="T_862b5_row12_col0" class="data row12 col0" >7</td>
#       <td id="T_862b5_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_862b5_row12_col2" class="data row12 col2" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# best team in chasing the score

sql=""" select 
        case when Toss_Winner=Team_1 and Toss_Decide=2 then c.Team_Name
             when Toss_Winner=Team_1 and Toss_Decide=1 then b.Team_Name
             when Toss_Winner=Team_2 and Toss_Decide=2 then b.Team_Name
             else c.Team_Name end as franchise,
        count(Match_Id) as matches,sum(case when Win_Type==2 then 1 else 0 end)as wins,
        round(round(sum(case when Win_Type==2 then 1 else 0 end),2)/round(count(Match_Id),2),2) as win_percentage
        from Match a
        join Team b
        on a.Team_1=b.Team_Id
        join Team c
        on a.Team_2=c.Team_Id
        group by franchise
        order by win_percentage desc; """

best_chasers=pd.read_sql(sql, conn).set_index("franchise")
best_chasers.style.background_gradient(subset=["win_percentage"],cmap="Oranges",high=0.5)
# Out:
# <style type="text/css">
# #T_67b37_row0_col2 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_67b37_row1_col2 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_67b37_row2_col2 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_67b37_row3_col2 {
#   background-color: #fda25a;
#   color: #000000;
# }
# #T_67b37_row4_col2 {
#   background-color: #fda55f;
#   color: #000000;
# }
# #T_67b37_row5_col2 {
#   background-color: #fda863;
#   color: #000000;
# }
# #T_67b37_row6_col2 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_67b37_row7_col2 {
#   background-color: #fdaf6c;
#   color: #000000;
# }
# #T_67b37_row8_col2 {
#   background-color: #fdbb81;
#   color: #000000;
# }
# #T_67b37_row9_col2 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_67b37_row10_col2 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_67b37_row11_col2 {
#   background-color: #fee6ce;
#   color: #000000;
# }
# #T_67b37_row12_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_67b37_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >matches</th>
#       <th class="col_heading level0 col1" >wins</th>
#       <th class="col_heading level0 col2" >win_percentage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >franchise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67b37_level0_row0" class="row_heading level0 row0" >Gujarat Lions</th>
#       <td id="T_67b37_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_67b37_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_67b37_row0_col2" class="data row0 col2" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row1" class="row_heading level0 row1" >Chennai Super Kings</th>
#       <td id="T_67b37_row1_col0" class="data row1 col0" >54</td>
#       <td id="T_67b37_row1_col1" class="data row1 col1" >33</td>
#       <td id="T_67b37_row1_col2" class="data row1 col2" >0.610000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row2" class="row_heading level0 row2" >Sunrisers Hyderabad</th>
#       <td id="T_67b37_row2_col0" class="data row2 col0" >25</td>
#       <td id="T_67b37_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_67b37_row2_col2" class="data row2 col2" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row3" class="row_heading level0 row3" >Rajasthan Royals</th>
#       <td id="T_67b37_row3_col0" class="data row3 col0" >64</td>
#       <td id="T_67b37_row3_col1" class="data row3 col1" >38</td>
#       <td id="T_67b37_row3_col2" class="data row3 col2" >0.590000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row4" class="row_heading level0 row4" >Mumbai Indians</th>
#       <td id="T_67b37_row4_col0" class="data row4 col0" >64</td>
#       <td id="T_67b37_row4_col1" class="data row4 col1" >37</td>
#       <td id="T_67b37_row4_col2" class="data row4 col2" >0.580000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row5" class="row_heading level0 row5" >Kochi Tuskers Kerala</th>
#       <td id="T_67b37_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_67b37_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_67b37_row5_col2" class="data row5 col2" >0.570000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row6" class="row_heading level0 row6" >Kolkata Knight Riders</th>
#       <td id="T_67b37_row6_col0" class="data row6 col0" >70</td>
#       <td id="T_67b37_row6_col1" class="data row6 col1" >39</td>
#       <td id="T_67b37_row6_col2" class="data row6 col2" >0.560000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row7" class="row_heading level0 row7" >Royal Challengers Bangalore</th>
#       <td id="T_67b37_row7_col0" class="data row7 col0" >77</td>
#       <td id="T_67b37_row7_col1" class="data row7 col1" >42</td>
#       <td id="T_67b37_row7_col2" class="data row7 col2" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row8" class="row_heading level0 row8" >Kings XI Punjab</th>
#       <td id="T_67b37_row8_col0" class="data row8 col0" >65</td>
#       <td id="T_67b37_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_67b37_row8_col2" class="data row8 col2" >0.510000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row9" class="row_heading level0 row9" >Delhi Daredevils</th>
#       <td id="T_67b37_row9_col0" class="data row9 col0" >76</td>
#       <td id="T_67b37_row9_col1" class="data row9 col1" >38</td>
#       <td id="T_67b37_row9_col2" class="data row9 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row10" class="row_heading level0 row10" >Rising Pune Supergiants</th>
#       <td id="T_67b37_row10_col0" class="data row10 col0" >7</td>
#       <td id="T_67b37_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_67b37_row10_col2" class="data row10 col2" >0.430000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row11" class="row_heading level0 row11" >Deccan Chargers</th>
#       <td id="T_67b37_row11_col0" class="data row11 col0" >32</td>
#       <td id="T_67b37_row11_col1" class="data row11 col1" >11</td>
#       <td id="T_67b37_row11_col2" class="data row11 col2" >0.340000</td>
#     </tr>
#     <tr>
#       <th id="T_67b37_level0_row12" class="row_heading level0 row12" >Pune Warriors</th>
#       <td id="T_67b37_row12_col0" class="data row12 col0" >26</td>
#       <td id="T_67b37_row12_col1" class="data row12 col1" >6</td>
#       <td id="T_67b37_row12_col2" class="data row12 col2" >0.230000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Best Teams in IPL

sql=""" select Team_Name as Team,
        a.matches+b.matches as Matches,c.Wins,
        round(round(Wins,2)/round(a.matches+b.matches,2),2) as Win_perc,
        Defending_perc,Chasing_perc
        from( select Team_1,
              count(*) as matches
              from Match
              group by Team_1) a
        join( select Team_2,
              count(*) as matches
              from Match
              group by Team_2) b
        on a.Team_1=b.Team_2
        join (select Match_Winner,
              count(*) as Wins
              from Match
              where Match_Winner is not null
              group by Match_Winner) c
        on a.Team_1=c.Match_Winner
        join( select 
              case when Toss_Winner=Team_1 and Toss_Decide=2 then Team_1
                   when Toss_Winner=Team_1 and Toss_Decide=1 then Team_2
                   when Toss_Winner=Team_2 and Toss_Decide=2 then Team_2
                   else Team_1 end as franchise,
              round(round(sum(case when Win_Type==1 then 1 else 0 end),2)/round(count(Match_Id),2),2) as Defending_perc
              from Match 
              where Outcome_type=1 
              group by franchise) d
        on a.Team_1=d.franchise
        join( select 
              case when Toss_Winner=Team_1 and Toss_Decide=2 then Team_2
                   when Toss_Winner=Team_1 and Toss_Decide=1 then Team_1
                   when Toss_Winner=Team_2 and Toss_Decide=2 then Team_1
                   else Team_2 end as franchise,
              round(round(sum(case when Win_Type==2 then 1 else 0 end),2)/round(count(Match_Id),2),2) as Chasing_perc
              from Match 
              where Outcome_type=1
              group by franchise) e
        on a.Team_1=e.franchise
        join Team f
        on a.Team_1=f.Team_Id
        order by Win_perc desc,Chasing_perc desc,Defending_perc desc; """

best_teams=pd.read_sql(sql, conn)
subset=["Win_perc","Defending_perc","Chasing_perc"]
best_teams.style.background_gradient(subset=subset,cmap="Oranges",high=0.5)
# Out:
# <style type="text/css">
# #T_d12fb_row0_col3, #T_d12fb_row0_col4, #T_d12fb_row2_col5 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_d12fb_row0_col5 {
#   background-color: #fd9a4e;
#   color: #000000;
# }
# #T_d12fb_row1_col3 {
#   background-color: #f36e19;
#   color: #f1f1f1;
# }
# #T_d12fb_row1_col4 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_d12fb_row1_col5 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_d12fb_row2_col3 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_d12fb_row2_col4 {
#   background-color: #fddbb8;
#   color: #000000;
# }
# #T_d12fb_row3_col3, #T_d12fb_row3_col4 {
#   background-color: #f67925;
#   color: #f1f1f1;
# }
# #T_d12fb_row3_col5 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_d12fb_row4_col3 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_d12fb_row4_col4, #T_d12fb_row5_col4, #T_d12fb_row6_col4 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_d12fb_row4_col5 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_d12fb_row5_col3 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_d12fb_row5_col5, #T_d12fb_row8_col5 {
#   background-color: #fda965;
#   color: #000000;
# }
# #T_d12fb_row6_col3 {
#   background-color: #fd9547;
#   color: #000000;
# }
# #T_d12fb_row6_col5 {
#   background-color: #fdad69;
#   color: #000000;
# }
# #T_d12fb_row7_col3, #T_d12fb_row9_col4 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_d12fb_row7_col4 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_d12fb_row7_col5, #T_d12fb_row8_col3, #T_d12fb_row12_col4 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_d12fb_row8_col4 {
#   background-color: #fdbd83;
#   color: #000000;
# }
# #T_d12fb_row9_col3 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_d12fb_row9_col5 {
#   background-color: #fdc088;
#   color: #000000;
# }
# #T_d12fb_row10_col3 {
#   background-color: #fdcfa0;
#   color: #000000;
# }
# #T_d12fb_row10_col4 {
#   background-color: #fd9649;
#   color: #000000;
# }
# #T_d12fb_row10_col5 {
#   background-color: #fee7d0;
#   color: #000000;
# }
# #T_d12fb_row11_col3 {
#   background-color: #fdd9b5;
#   color: #000000;
# }
# #T_d12fb_row11_col4, #T_d12fb_row12_col3, #T_d12fb_row12_col5 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_d12fb_row11_col5 {
#   background-color: #fdd5ab;
#   color: #000000;
# }
# </style>
# <table id="T_d12fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team</th>
#       <th class="col_heading level0 col1" >Matches</th>
#       <th class="col_heading level0 col2" >Wins</th>
#       <th class="col_heading level0 col3" >Win_perc</th>
#       <th class="col_heading level0 col4" >Defending_perc</th>
#       <th class="col_heading level0 col5" >Chasing_perc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d12fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d12fb_row0_col0" class="data row0 col0" >Chennai Super Kings</td>
#       <td id="T_d12fb_row0_col1" class="data row0 col1" >131</td>
#       <td id="T_d12fb_row0_col2" class="data row0 col2" >79</td>
#       <td id="T_d12fb_row0_col3" class="data row0 col3" >0.600000</td>
#       <td id="T_d12fb_row0_col4" class="data row0 col4" >0.600000</td>
#       <td id="T_d12fb_row0_col5" class="data row0 col5" >0.620000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d12fb_row1_col0" class="data row1 col0" >Mumbai Indians</td>
#       <td id="T_d12fb_row1_col1" class="data row1 col1" >140</td>
#       <td id="T_d12fb_row1_col2" class="data row1 col2" >80</td>
#       <td id="T_d12fb_row1_col3" class="data row1 col3" >0.570000</td>
#       <td id="T_d12fb_row1_col4" class="data row1 col4" >0.570000</td>
#       <td id="T_d12fb_row1_col5" class="data row1 col5" >0.580000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d12fb_row2_col0" class="data row2 col0" >Gujarat Lions</td>
#       <td id="T_d12fb_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_d12fb_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_d12fb_row2_col3" class="data row2 col3" >0.560000</td>
#       <td id="T_d12fb_row2_col4" class="data row2 col4" >0.170000</td>
#       <td id="T_d12fb_row2_col5" class="data row2 col5" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d12fb_row3_col0" class="data row3 col0" >Sunrisers Hyderabad</td>
#       <td id="T_d12fb_row3_col1" class="data row3 col1" >62</td>
#       <td id="T_d12fb_row3_col2" class="data row3 col2" >34</td>
#       <td id="T_d12fb_row3_col3" class="data row3 col3" >0.550000</td>
#       <td id="T_d12fb_row3_col4" class="data row3 col4" >0.510000</td>
#       <td id="T_d12fb_row3_col5" class="data row3 col5" >0.630000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d12fb_row4_col0" class="data row4 col0" >Rajasthan Royals</td>
#       <td id="T_d12fb_row4_col1" class="data row4 col1" >118</td>
#       <td id="T_d12fb_row4_col2" class="data row4 col2" >63</td>
#       <td id="T_d12fb_row4_col3" class="data row4 col3" >0.530000</td>
#       <td id="T_d12fb_row4_col4" class="data row4 col4" >0.450000</td>
#       <td id="T_d12fb_row4_col5" class="data row4 col5" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d12fb_row5_col0" class="data row5 col0" >Kolkata Knight Riders</td>
#       <td id="T_d12fb_row5_col1" class="data row5 col1" >132</td>
#       <td id="T_d12fb_row5_col2" class="data row5 col2" >68</td>
#       <td id="T_d12fb_row5_col3" class="data row5 col3" >0.520000</td>
#       <td id="T_d12fb_row5_col4" class="data row5 col4" >0.450000</td>
#       <td id="T_d12fb_row5_col5" class="data row5 col5" >0.570000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d12fb_row6_col0" class="data row6 col0" >Royal Challengers Bangalore</td>
#       <td id="T_d12fb_row6_col1" class="data row6 col1" >139</td>
#       <td id="T_d12fb_row6_col2" class="data row6 col2" >70</td>
#       <td id="T_d12fb_row6_col3" class="data row6 col3" >0.500000</td>
#       <td id="T_d12fb_row6_col4" class="data row6 col4" >0.450000</td>
#       <td id="T_d12fb_row6_col5" class="data row6 col5" >0.560000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d12fb_row7_col0" class="data row7 col0" >Kings XI Punjab</td>
#       <td id="T_d12fb_row7_col1" class="data row7 col1" >134</td>
#       <td id="T_d12fb_row7_col2" class="data row7 col2" >63</td>
#       <td id="T_d12fb_row7_col3" class="data row7 col3" >0.470000</td>
#       <td id="T_d12fb_row7_col4" class="data row7 col4" >0.410000</td>
#       <td id="T_d12fb_row7_col5" class="data row7 col5" >0.520000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d12fb_row8_col0" class="data row8 col0" >Kochi Tuskers Kerala</td>
#       <td id="T_d12fb_row8_col1" class="data row8 col1" >14</td>
#       <td id="T_d12fb_row8_col2" class="data row8 col2" >6</td>
#       <td id="T_d12fb_row8_col3" class="data row8 col3" >0.430000</td>
#       <td id="T_d12fb_row8_col4" class="data row8 col4" >0.290000</td>
#       <td id="T_d12fb_row8_col5" class="data row8 col5" >0.570000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d12fb_row9_col0" class="data row9 col0" >Delhi Daredevils</td>
#       <td id="T_d12fb_row9_col1" class="data row9 col1" >133</td>
#       <td id="T_d12fb_row9_col2" class="data row9 col2" >56</td>
#       <td id="T_d12fb_row9_col3" class="data row9 col3" >0.420000</td>
#       <td id="T_d12fb_row9_col4" class="data row9 col4" >0.370000</td>
#       <td id="T_d12fb_row9_col5" class="data row9 col5" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d12fb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d12fb_row10_col0" class="data r

# %% [markdown]
# ### Season Statistics

# %%
# IPL Season's Best PLayers

sql=""" select Season_Year,
        b.Player_Name as Man_of_Season,
        c.Player_Name as Top_Scorer,
        d.Player_Name as Top_Wicket_Tacker
        from Season a
        join Player b
        on a.Man_of_the_Series=b.Player_Id
        join Player c
        on a.Orange_Cap=c.Player_Id
        join Player d
        on a.Purple_Cap=d.Player_Id; """

top_perfomer=pd.read_sql(sql, conn).set_index("Season_Year")
top_perfomer
# Out:
#             Man_of_Season    Top_Scorer Top_Wicket_Tacker
# Season_Year
# 2008            SR Watson      SE Marsh     Sohail Tanvir
# 2009         AC Gilchrist     ML Hayden          RP Singh
# 2010         SR Tendulkar  SR Tendulkar           PP Ojha
# 2011             CH Gayle      CH Gayle        SL Malinga
# 2012            SP Narine      CH Gayle          M Morkel
# 2013            SR Watson    MEK Hussey          DJ Bravo
# 2014           GJ Maxwell    RV Uthappa         MM Sharma
# 2015           AD Russell     DA Warner          DJ Bravo
# 2016              V Kohli       V Kohli           B Kumar

# %%
# IPL Season's Winners,Runners Up, Win Type

sql=""" select Season_Year,c.Team_Name as Winner,d.Team_Name as Runner_Up
        from( select Season_Id,
              case when Team_1=Match_Winner then Team_1 
              else Team_2 end as first,
              case when Team_1!=Match_Winner then Team_1 
              else Team_2 end as second
              from (select Season_Id,Team_1,Team_2,Match_Winner
                    from Match
                    group by Season_Id
                    having Match_Id=max(Match_Id))) a
        join Season b
        on a.Season_Id=b.Season_Id
        join Team c
        on a.first=c.Team_Id
        join Team d
        on a.second=d.Team_Id; """

season_winner=pd.read_sql(sql, conn).set_index("Season_Year")
season_winner
# Out:
#                             Winner                    Runner_Up
# Season_Year
# 2008              Rajasthan Royals          Chennai Super Kings
# 2009               Deccan Chargers  Royal Challengers Bangalore
# 2010           Chennai Super Kings               Mumbai Indians
# 2011           Chennai Super Kings  Royal Challengers Bangalore
# 2012         Kolkata Knight Riders          Chennai Super Kings
# 2013                Mumbai Indians          Chennai Super Kings
# 2014         Kolkata Knight Riders              Kings XI Punjab
# 2015                Mumbai Indians          Chennai Super Kings
# 2016           Sunrisers Hyderabad  Royal Challengers Bangalore

# %%
# Runs scored in powerplay,middle and death overs in different seasons of IPL

sql=""" select Season_Year,Matches,
        sum(case when a.Over_Id<=6 then Runs_Scored+coalesce(Extra_Runs,0) else 0 end) as powerplay,
        sum(case when a.Over_Id>6 and a.Over_Id<=15 then Runs_Scored+coalesce(Extra_Runs,0) else 0 end) as middleovers,
        sum(case when a.Over_Id>15 then Runs_Scored+coalesce(Extra_Runs,0) else 0 end) as deathovers
        from Batsman_Scored a
        join Match b
        on a.Match_Id==b.Match_Id
        left join Extra_Runs c
        on a.Match_Id=c.Match_Id 
        and a.Innings_No=c.Innings_No
        and a.Over_Id=c.Over_Id
        and a.Ball_Id=c.Ball_Id
        join Season d
        on b.Season_Id==d.Season_Id
        join (select Season_Id,
              count(Match_Id) as Matches
              from Match 
              group by Season_Id) e
        on b.Season_Id==e.Season_Id
        group by d.Season_Year; """

runs_season=pd.read_sql(sql, conn).set_index("Season_Year")
subset=["powerplay","middleovers","deathovers"]
runs_season.head().style.background_gradient(subset=subset,cmap="YlOrRd",high=0.5)
# Out:
# <style type="text/css">
# #T_0fb4a_row0_col1 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_0fb4a_row0_col2 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_0fb4a_row0_col3 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_0fb4a_row1_col1, #T_0fb4a_row1_col2, #T_0fb4a_row1_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_0fb4a_row2_col1 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_0fb4a_row2_col2 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_0fb4a_row2_col3 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_0fb4a_row3_col1 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_0fb4a_row3_col2 {
#   background-color: #fd7435;
#   color: #f1f1f1;
# }
# #T_0fb4a_row3_col3 {
#   background-color: #fec561;
#   color: #000000;
# }
# #T_0fb4a_row4_col1, #T_0fb4a_row4_col2, #T_0fb4a_row4_col3 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0fb4a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Matches</th>
#       <th class="col_heading level0 col1" >powerplay</th>
#       <th class="col_heading level0 col2" >middleovers</th>
#       <th class="col_heading level0 col3" >deathovers</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Season_Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fb4a_level0_row0" class="row_heading level0 row0" >2008</th>
#       <td id="T_0fb4a_row0_col0" class="data row0 col0" >58</td>
#       <td id="T_0fb4a_row0_col1" class="data row0 col1" >5111</td>
#       <td id="T_0fb4a_row0_col2" class="data row0 col2" >7821</td>
#       <td id="T_0fb4a_row0_col3" class="data row0 col3" >4400</td>
#     </tr>
#     <tr>
#       <th id="T_0fb4a_level0_row1" class="row_heading level0 row1" >2009</th>
#       <td id="T_0fb4a_row1_col0" class="data row1 col0" >57</td>
#       <td id="T_0fb4a_row1_col1" class="data row1 col1" >4749</td>
#       <td id="T_0fb4a_row1_col2" class="data row1 col2" >6695</td>
#       <td id="T_0fb4a_row1_col3" class="data row1 col3" >4382</td>
#     </tr>
#     <tr>
#       <th id="T_0fb4a_level0_row2" class="row_heading level0 row2" >2010</th>
#       <td id="T_0fb4a_row2_col0" class="data row2 col0" >60</td>
#       <td id="T_0fb4a_row2_col1" class="data row2 col1" >5445</td>
#       <td id="T_0fb4a_row2_col2" class="data row2 col2" >7860</td>
#       <td id="T_0fb4a_row2_col3" class="data row2 col3" >4939</td>
#     </tr>
#     <tr>
#       <th id="T_0fb4a_level0_row3" class="row_heading level0 row3" >2011</th>
#       <td id="T_0fb4a_row3_col0" class="data row3 col0" >73</td>
#       <td id="T_0fb4a_row3_col1" class="data row3 col1" >5998</td>
#       <td id="T_0fb4a_row3_col2" class="data row3 col2" >9236</td>
#       <td id="T_0fb4a_row3_col3" class="data row3 col3" >5264</td>
#     </tr>
#     <tr>
#       <th id="T_0fb4a_level0_row4" class="row_heading level0 row4" >2012</th>
#       <td id="T_0fb4a_row4_col0" class="data row4 col0" >74</td>
#       <td id="T_0fb4a_row4_col1" class="data row4 col1" >6404</td>
#       <td id="T_0fb4a_row4_col2" class="data row4 col2" >9771</td>
#       <td id="T_0fb4a_row4_col3" class="data row4 col3" >6252</td>
#     </tr>
#   </tbody>
# </table>

# %%
#highest score of a Season 

sql=""" select Season_Year,
        case when a.Innings_No==1 then c.Team_Name 
             else d.Team_Name end as batting_team,
        case when a.Innings_No==1 then d.Team_Name 
             else c.Team_Name end as fielding_team,
        max(runs+extra) as Score,City_Name
        from(select Season_Year,sum(Runs_Scored) as runs,
             a.Match_Id,a.Innings_No,Venue_id,
             case when Toss_Winner==Team_1 and Toss_Decide==1 then Team_2
                  when Toss_Winner==Team_1 and Toss_Decide==2 then Team_1
                  when Toss_Winner==Team_2 and Toss_Decide==1 then Team_1
                  else Team_2 end as batting,
             case when Toss_Winner==Team_1 and Toss_Decide==1 then Team_1
                  when Toss_Winner==Team_1 and Toss_Decide==2 then Team_2
                  when Toss_Winner==Team_2 and Toss_Decide==1 then Team_2
                  else Team_1 end as fielding
            from Batsman_Scored a
            join Match b
            on a.Match_Id=b.Match_Id
            join Season d
            on b.Season_Id=d.Season_Id
            group by Season_Year, a.Match_Id, a.Innings_No) a
        join (select Match_Id,Innings_No,sum(Extra_Runs) as extra
                  from Extra_Runs
                  group by Match_Id,Innings_No) b
        on a.Match_Id=b.Match_Id 
        and a.Innings_No=b.Innings_No
        join Team c
        on a.batting=c.Team_Id
        join Team d
        on a.fielding=d.Team_Id
        join (Select Venue_Id,Venue_Name,City_Name
              from Venue a
              join City b
              on a.City_Id=b.City_Id) e
        on a.Venue_Id=e.Venue_Id
        group by Season_Year; """

Season_highest=pd.read_sql(sql, conn).set_index("Season_Year")
Season_highest.head().style.background_gradient(subset=["Score"],cmap="YlOrRd",high=0.5)
# Out:
# <style type="text/css">
# #T_21c4a_row0_col2 {
#   background-color: #fd7234;
#   color: #f1f1f1;
# }
# #T_21c4a_row1_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_21c4a_row2_col2 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_21c4a_row3_col2 {
#   background-color: #feab49;
#   color: #000000;
# }
# #T_21c4a_row4_col2 {
#   background-color: #fee084;
#   color: #000000;
# }
# </style>
# <table id="T_21c4a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >batting_team</th>
#       <th class="col_heading level0 col1" >fielding_team</th>
#       <th class="col_heading level0 col2" >Score</th>
#       <th class="col_heading level0 col3" >City_Name</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Season_Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21c4a_level0_row0" class="row_heading level0 row0" >2008</th>
#       <td id="T_21c4a_row0_col0" class="data row0 col0" >Chennai Super Kings</td>
#       <td id="T_21c4a_row0_col1" class="data row0 col1" >Kings XI Punjab</td>
#       <td id="T_21c4a_row0_col2" class="data row0 col2" >240</td>
#       <td id="T_21c4a_row0_col3" class="data row0 col3" >Chandigarh</td>
#     </tr>
#     <tr>
#       <th id="T_21c4a_level0_row1" class="row_heading level0 row1" >2009</th>
#       <td id="T_21c4a_row1_col0" class="data row1 col0" >Rajasthan Royals</td>
#       <td id="T_21c4a_row1_col1" class="data row1 col1" >Kings XI Punjab</td>
#       <td id="T_21c4a_row1_col2" class="data row1 col2" >211</td>
#       <td id="T_21c4a_row1_col3" class="data row1 col3" >Durban</td>
#     </tr>
#     <tr>
#       <th id="T_21c4a_level0_row2" class="row_heading level0 row2" >2010</th>
#       <td id="T_21c4a_row2_col0" class="data row2 col0" >Chennai Super Kings</td>
#       <td id="T_21c4a_row2_col1" class="data row2 col1" >Rajasthan Royals</td>
#       <td id="T_21c4a_row2_col2" class="data row2 col2" >246</td>
#       <td id="T_21c4a_row2_col3" class="data row2 col3" >Chennai</td>
#     </tr>
#     <tr>
#       <th id="T_21c4a_level0_row3" class="row_heading level0 row3" >2011</th>
#       <td id="T_21c4a_row3_col0" class="data row3 col0" >Kings XI Punjab</td>
#       <td id="T_21c4a_row3_col1" class="data row3 col1" >Royal Challengers Bangalore</td>
#       <td id="T_21c4a_row3_col2" class="data row3 col2" >232</td>
#       <td id="T_21c4a_row3_col3" class="data row3 col3" >Dharamsala</td>
#     </tr>
#     <tr>
#       <th id="T_21c4a_level0_row4" class="row_heading level0 row4" >2012</th>
#       <td id="T_21c4a_row4_col0" class="data row4 col0" >Chennai Super Kings</td>
#       <td id="T_21c4a_row4_col1" class="data row4 col1" >Delhi Daredevils</td>
#       <td id="T_21c4a_row4_col2" class="data row4 col2" >222</td>
#       <td id="T_21c4a_row4_col3" class="data row4 col3" >Chennai</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Lowest score of a Season 

sql=""" select Season_Year,
        case when a.Innings_No==1 then c.Team_Name 
             else d.Team_Name end as batting_team,
        case when a.Innings_No==1 then d.Team_Name 
             else c.Team_Name end as fielding_team,
        min(runs+extra) as Score,City_Name
        from(select Season_Year,sum(Runs_Scored) as runs,
             a.Match_Id,a.Innings_No,Venue_id,
             case when Toss_Winner==Team_1 and Toss_Decide==1 then Team_2
                  when Toss_Winner==Team_1 and Toss_Decide==2 then Team_1
                  when Toss_Winner==Team_2 and Toss_Decide==1 then Team_1
                  else Team_2 end as batting,
             case when Toss_Winner==Team_1 and Toss_Decide==1 then Team_1
                  when Toss_Winner==Team_1 and Toss_Decide==2 then Team_2
                  when Toss_Winner==Team_2 and Toss_Decide==1 then Team_2
                  else Team_1 end as fielding
            from Batsman_Scored a
            join Match b
            on a.Match_Id=b.Match_Id
            join Season d
            on b.Season_Id=d.Season_Id
            where Win_Type not in (3,4)
            group by Season_Year, a.Match_Id, a.Innings_No) a
        join (select Match_Id,Innings_No,sum(Extra_Runs) as extra
                  from Extra_Runs
                  group by Match_Id,Innings_No) b
        on a.Match_Id=b.Match_Id 
        and a.Innings_No=b.Innings_No
        join Team c
        on a.batting=c.Team_Id
        join Team d
        on a.fielding=d.Team_Id
        join (Select Venue_Id,Venue_Name,City_Name
              from Venue a
              join City b
              on a.City_Id=b.City_Id) e
        on a.Venue_Id=e.Venue_Id
        group by Season_Year; """

Season_lowest=pd.read_sql(sql, conn).set_index("Season_Year")
Season_lowest.head().style.background_gradient(subset=["Score"],cmap="YlOrRd",high=0.5)
# Out:
# <style type="text/css">
# #T_de133_row0_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_de133_row1_col2 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_de133_row2_col2 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_de133_row3_col2 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_de133_row4_col2 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_de133_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >batting_team</th>
#       <th class="col_heading level0 col1" >fielding_team</th>
#       <th class="col_heading level0 col2" >Score</th>
#       <th class="col_heading level0 col3" >City_Name</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Season_Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de133_level0_row0" class="row_heading level0 row0" >2008</th>
#       <td id="T_de133_row0_col0" class="data row0 col0" >Chennai Super Kings</td>
#       <td id="T_de133_row0_col1" class="data row0 col1" >Kolkata Knight Riders</td>
#       <td id="T_de133_row0_col2" class="data row0 col2" >55</td>
#       <td id="T_de133_row0_col3" class="data row0 col3" >Kolkata</td>
#     </tr>
#     <tr>
#       <th id="T_de133_level0_row1" class="row_heading level0 row1" >2009</th>
#       <td id="T_de133_row1_col0" class="data row1 col0" >Rajasthan Royals</td>
#       <td id="T_de133_row1_col1" class="data row1 col1" >Royal Challengers Bangalore</td>
#       <td id="T_de133_row1_col2" class="data row1 col2" >58</td>
#       <td id="T_de133_row1_col3" class="data row1 col3" >Cape Town</td>
#     </tr>
#     <tr>
#       <th id="T_de133_level0_row2" class="row_heading level0 row2" >2010</th>
#       <td id="T_de133_row2_col0" class="data row2 col0" >Deccan Chargers</td>
#       <td id="T_de133_row2_col1" class="data row2 col1" >Royal Challengers Bangalore</td>
#       <td id="T_de133_row2_col2" class="data row2 col2" >82</td>
#       <td id="T_de133_row2_col3" class="data row2 col3" >Mumbai</td>
#     </tr>
#     <tr>
#       <th id="T_de133_level0_row3" class="row_heading level0 row3" >2011</th>
#       <td id="T_de133_row3_col0" class="data row3 col0" >Kolkata Knight Riders</td>
#       <td id="T_de133_row3_col1" class="data row3 col1" >Chennai Super Kings</td>
#       <td id="T_de133_row3_col2" class="data row3 col2" >61</td>
#       <td id="T_de133_row3_col3" class="data row3 col3" >Kolkata</td>
#     </tr>
#     <tr>
#       <th id="T_de133_level0_row4" class="row_heading level0 row4" >2012</th>
#       <td id="T_de133_row4_col0" class="data row4 col0" >Mumbai Indians</td>
#       <td id="T_de133_row4_col1" class="data row4 col1" >Delhi Daredevils</td>
#       <td id="T_de133_row4_col2" class="data row4 col2" >92</td>
#       <td id="T_de133_row4_col3" class="data row4 col3" >Mumbai</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Season Wise Team Performance

sql=""" select Season_Year,Team_Name,
        a.matches+b.matches as Matches,c.Wins,
        round(round(Wins,2)/round(a.matches+b.matches,2),2) as Win_perc,
        Defending_perc,Chasing_perc
        from( select Season_Id,Team_1,
              count(*) as matches
              from Match
              group by Season_Id,Team_1) a
        join( select Season_Id,Team_2,
              count(*) as matches
              from Match
              group by Season_Id,Team_2) b
        on a.Season_Id=b.Season_Id
        and a.Team_1=b.Team_2
        join (select Season_Id,Match_Winner,
              count(*) as Wins
              from Match
              where Match_Winner is not null
              group by Season_Id,Match_Winner) c
        on a.Season_Id=c.Season_Id
        and a.Team_1=c.Match_Winner
        join( select Season_Id,
              case when Toss_Winner=Team_1 and Toss_Decide=2 then Team_1
                   when Toss_Winner=Team_1 and Toss_Decide=1 then Team_2
                   when Toss_Winner=Team_2 and Toss_Decide=2 then Team_2
                   else Team_1 end as franchise,
              round(round(sum(case when Win_Type==1 then 1 else 0 end),2)/round(count(Match_Id),2),2) as Defending_perc
              from Match 
              where Outcome_type=1 
              group by Season_Id,franchise) d
        on a.Season_Id=d.Season_Id
        and a.Team_1=d.franchise
        join( select Season_Id,
              case when Toss_Winner=Team_1 and Toss_Decide=2 then Team_2
                   when Toss_Winner=Team_1 and Toss_Decide=1 then Team_1
                   when Toss_Winner=Team_2 and Toss_Decide=2 then Team_1
                   else Team_2 end as franchise,
              round(round(sum(case when Win_Type==2 then 1 else 0 end),2)/round(count(Match_Id),2),2) as Chasing_perc
              from Match 
              where Outcome_type=1
              group by Season_Id,franchise) e
        on a.Season_Id=e.Season_Id
        and a.Team_1=e.franchise
        join Team f
        on a.Team_1=f.Team_Id
        join Season g
        on a.Season_Id=g.Season_Id
        order by a.Season_Id,Matches desc,Wins desc,Chasing_perc desc; """

beta=pd.read_sql(sql, conn).set_index(keys=["Season_Year","Team_Name"])

# Select Season year to display, default=2016
subset=["Wins","Win_perc","Defending_perc","Chasing_perc"]
beta.loc[2016].style.background_gradient(subset=subset,cmap="YlOrRd",high=0.5)
# Out:
# <style type="text/css">
# #T_fa39f_row0_col1, #T_fa39f_row0_col2, #T_fa39f_row0_col3, #T_fa39f_row1_col4 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_fa39f_row0_col4, #T_fa39f_row3_col4 {
#   background-color: #fc5d2e;
#   color: #f1f1f1;
# }
# #T_fa39f_row1_col1, #T_fa39f_row2_col1 {
#   background-color: #fd953f;
#   color: #000000;
# }
# #T_fa39f_row1_col2, #T_fa39f_row2_col2 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_fa39f_row1_col3 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_fa39f_row2_col3, #T_fa39f_row5_col3 {
#   background-color: #fd8e3c;
#   color: #f1f1f1;
# }
# #T_fa39f_row2_col4 {
#   background-color: #fd923e;
#   color: #000000;
# }
# #T_fa39f_row3_col1 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_fa39f_row3_col2 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_fa39f_row3_col3, #T_fa39f_row4_col1, #T_fa39f_row4_col3, #T_fa39f_row5_col1 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_fa39f_row4_col2, #T_fa39f_row5_col2 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_fa39f_row4_col4 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_fa39f_row5_col4 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_fa39f_row6_col1 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_fa39f_row6_col2 {
#   background-color: #ffec9f;
#   color: #000000;
# }
# #T_fa39f_row6_col3, #T_fa39f_row7_col1, #T_fa39f_row7_col2, #T_fa39f_row7_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_fa39f_row6_col4 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_fa39f_row7_col3 {
#   background-color: #fed977;
#   color: #000000;
# }
# </style>
# <table id="T_fa39f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Matches</th>
#       <th class="col_heading level0 col1" >Wins</th>
#       <th class="col_heading level0 col2" >Win_perc</th>
#       <th class="col_heading level0 col3" >Defending_perc</th>
#       <th class="col_heading level0 col4" >Chasing_perc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Team_Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa39f_level0_row0" class="row_heading level0 row0" >Sunrisers Hyderabad</th>
#       <td id="T_fa39f_row0_col0" class="data row0 col0" >17</td>
#       <td id="T_fa39f_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_fa39f_row0_col2" class="data row0 col2" >0.650000</td>
#       <td id="T_fa39f_row0_col3" class="data row0 col3" >0.670000</td>
#       <td id="T_fa39f_row0_col4" class="data row0 col4" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_fa39f_level0_row1" class="row_heading level0 row1" >Gujarat Lions</th>
#       <td id="T_fa39f_row1_col0" class="data row1 col0" >16</td>
#       <td id="T_fa39f_row1_col1" class="data row1 col1" >9</td>
#       <td id="T_fa39f_row1_col2" class="data row1 col2" >0.560000</td>
#       <td id="T_fa39f_row1_col3" class="data row1 col3" >0.170000</td>
#       <td id="T_fa39f_row1_col4" class="data row1 col4" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_fa39f_level0_row2" class="row_heading level0 row2" >Royal Challengers Bangalore</th>
#       <td id="T_fa39f_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_fa39f_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_fa39f_row2_col2" class="data row2 col2" >0.560000</td>
#       <td id="T_fa39f_row2_col3" class="data row2 col3" >0.500000</td>
#       <td id="T_fa39f_row2_col4" class="data row2 col4" >0.670000</td>
#     </tr>
#     <tr>
#       <th id="T_fa39f_level0_row3" class="row_heading level0 row3" >Kolkata Knight Riders</th>
#       <td id="T_fa39f_row3_col0" class="data row3 col0" >15</td>
#       <td id="T_fa39f_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_fa39f_row3_col2" class="data row3 col2" >0.530000</td>
#       <td id="T_fa39f_row3_col3" class="data row3 col3" >0.290000</td>
#       <td id="T_fa39f_row3_col4" class="data row3 col4" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_fa39f_level0_row4" class="row_heading level0 row4" >Mumbai Indians</th>
#       <td id="T_fa39f_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_fa39f_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_fa39f_row4_col2" class="data row4 col2" >0.500000</td>
#       <td id="T_fa39f_row4_col3" class="data row4 col3" >0.290000</td>
#       <td id="T_fa39f_row4_col4" class="data row4 col4" >0.710000</td>
#     </tr>
#     <tr>
#       <th id="T_fa39f_level0_row5" class="row_heading level0 row5" >Delhi Daredevils</th>
#       <td id="T_fa39f_row5_col0" class="data row5 col0" >14</td>
#       <td id="T_fa39f_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_fa39f_row5_col2" class="data row5 col2" >0.500000</td>
#       <td id="T_fa39f_row5_col3" class="data row5 col3" >0.500000</td>
#       <td id="T_fa39f_row5_col4" class="data row5 col4" >0.630000</td>
#     </tr>
#     <tr>
#       <th id="T_fa39f_level0_row6" class="row_heading level0 row6" >Rising Pune Supergiants</th>
#       <td id="T_fa39f_row6_col0" class="data row6 col0" >14</td>
#       <td id="T_fa39f_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_fa39f_row6_col2" class="data row6 col2" >0.360000</td>
#       <td id="T_fa39f_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_fa39f_row6_col4" class="data row6 col4" >0.430000</td>
#     </tr>
#     <tr>
#       <th id="T_fa39f_level0_row7" class="row_heading level0 row7" >Kings XI Punjab</th>
#       <td id="T_fa39f_row7_col0" class="data row7 col0" >14</td>
#       <td id="T_fa39f_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_fa39f_row7_col2" class="data row7 col2" >0.290000</td>
#       <td id="T_fa39f_row7_col3" class="data row7 col3" >0.250000</td>
#       <td id="T_fa39f_row7_col4" class="data row7 col4" >0.330000</td>
#     </tr>
#   </tbody>
# </table>
